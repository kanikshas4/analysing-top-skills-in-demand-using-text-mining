# %%
import pandas as pd
data = pd.read_csv (r' cloud_computing.csv')   
df = pd.DataFrame(data, columns= ['company','year_of_experience','description','skills'])
df
# Out:
#                                               company year_of_experience  \
# 0                                      E Hook Systems        10 - 13 yrs
# 1   IIBM Institute of Business Management\r\n     ...          0 - 3 yrs
# 2                Syncway Infotech\r\n     (More Jobs)          1 - 6 yrs
# 3              Aryan technologies\r\n     (More Jobs)          0 - 3 yrs
# 4              Aryan technologies\r\n     (More Jobs)          0 - 3 yrs
# 5                 Shah Recruiters\r\n     (More Jobs)          1 - 6 yrs
# 6                              HP ENTERPRISE SERVICES          2 - 3 yrs
# 7              Aryan technologies\r\n     (More Jobs)          0 - 3 yrs
# 8      Busibud Solutions Pvt. Ltd\r\n     (More Jobs)          0 - 3 yrs
# 9            CP Careers Pvt. Ltd.\r\n     (More Jobs)          6 - 9 yrs
# 10                      Mina Shaw\r\n     (More Jobs)          0 - 3 yrs
# 11                      Mina Shaw\r\n     (More Jobs)          0 - 3 yrs
# ...

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  passwd="apple123"
)
print(mydb)

# %%
mycursor = mydb.cursor()

# %%
mycursor.execute('SHOW DATABASES')

# %%
for datab in mycursor:
    print(datab)
# Out:
# ('information_schema',)
# ('mydb',)
# ('mysql',)
# ('performance_schema',)
# ('python_db',)
# ('sys',)

# %%
mycursor.execute('USE mydb')

# %%
mycursor.execute("CREATE TABLE mycloud_table (company VARCHAR(255),year_of_experience VARCHAR(255),description VARCHAR(255),skills VARCHAR(255))")

# %%
for i,row in df.iterrows():
            sql = "INSERT INTO mydb.mycloud_table VALUES (%s,%s,%s,%s)"
            mycursor.execute(sql, tuple(row))
            print("Record inserted")
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %%
# Execute query
sql = "SELECT * FROM mycloud_table "
mycursor.execute(sql)

# Fetch all the records
result = mycursor.fetchall()
for i in result:
    print(i)
# Out:
# ('E Hook Systems', '10 - 13 yrs', 'Cloud Computing Architect Responsibilities Knowledge of industry cloud computing principles and implementation of Cloud Computing conceptsKnowledge of designing a comprehensiv... More Details', 'information technology  ,  storage  ,  security  ,  devops  ,  json  ,  api  ,  cloud computing  ,  cloud services  ,  infrastructure  ,  openstack')
# ('IIBM Institute of Business Management\r\n     (More Jobs)', '0 - 3 yrs', 'IIBM Institute is hiring candidates for cloud computing  &  devops from pan India.candidate need to be fresher.must be graduate in any field.IIBM Institute had already trained... More Details', 'cloud computing  ,  devops  ,  azure  ,  aws')
# ('Syncway Infotech\r\n     (More Jobs)', '1 - 6 yrs', 'ast typing skills; Knowledge of touch typing system is strongly preferredExcellent knowledge of word processing tools and spreadsheets  ( MS Office Word ,  Excel etc. ) Basic ... More Details', '"Good Communication skills"')
# ...

# %%
import sqlalchemy
engine = sqlalchemy.create_engine('mysql://root:apple123@127.0.0.1') # connect to server

engine.execute("USE mydb")

# %%
# Insert whole DataFrame into MySQL
df.to_sql('mycloud_table', con = engine, if_exists = 'append', chunksize = 1000,index=False)

# %%
# Execute query
sql = "SELECT * FROM mycloud_table"
mycursor.execute(sql)
# Fetch all the records
result = mycursor.fetchall()
for i in result:
    print(i)
# Out:
# ('E Hook Systems', '10 - 13 yrs', 'Cloud Computing Architect Responsibilities Knowledge of industry cloud computing principles and implementation of Cloud Computing conceptsKnowledge of designing a comprehensiv... More Details', 'information technology  ,  storage  ,  security  ,  devops  ,  json  ,  api  ,  cloud computing  ,  cloud services  ,  infrastructure  ,  openstack')
# ('IIBM Institute of Business Management\r\n     (More Jobs)', '0 - 3 yrs', 'IIBM Institute is hiring candidates for cloud computing  &  devops from pan India.candidate need to be fresher.must be graduate in any field.IIBM Institute had already trained... More Details', 'cloud computing  ,  devops  ,  azure  ,  aws')
# ('Syncway Infotech\r\n     (More Jobs)', '1 - 6 yrs', 'ast typing skills; Knowledge of touch typing system is strongly preferredExcellent knowledge of word processing tools and spreadsheets  ( MS Office Word ,  Excel etc. ) Basic ... More Details', '"Good Communication skills"')
# ...

# %%
# Close the connection
if (mydb.is_connected()):
    mycursor.close()
    mydb.close()
