# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

URL = ("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Data+Scientist&txtLocation=North+India ")
#conducting a request of the stated URL above:
page3 = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup( page3.text, "html.parser")

# %%
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

# %%
for job in jobs:
    company=[]
    company1= job.find('h3',class_ ='joblist-comp-name')
    company.append(company1.text.strip())

# %%
print(company)
# Out:
# ['MASTERCARD']

# %%
company=[]
for job in jobs:
    company1= job.find('h3',class_ ='joblist-comp-name')
    company.append(company1.text.strip())

# %%
print(company)
# Out:
# ['Analytics Vidhya', 'Analytics Vidhya', 'Analytics Vidhya', 'Great Learning', 'Analytics Vidhya', 'Analytics Vidhya', 'Analytics Vidhya', 'Analytics Vidhya', 'Analytics Vidhya', 'ITFORTE STAFFING SERVICES PRIVATE LTD', 'axmiyan hr solutions private limited', 'Crowe LLP', 'Analytics Vidhya', 'Team Computers Pvt Ltd', 'electrifai', 'Analytics Vidhya', 'Sentieo', 'Beno Staffing', 'Analytics Vidhya', 'Analytics Vidhya', 'Pattem Digital Technologies', 'MASTERCARD', 'MASTERCARD', 'MASTERCARD', 'MASTERCARD']

# %%
year_of_experience =[]
for job in jobs:
    years=job.find('ul', class_='top-jd-dtl clearfix')
    for years in jobs:
        year=years.find('li').text.replace('card_travel','')
        
        year_of_experience.append(year.strip())

# %%
year_of_experience
# Out:
# ['2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '3 - 6 yrs',
#  '3 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '3 - 10 yrs',
#  '3 - 6 yrs',
#  '3 - 6 yrs',
#  '0 - 4 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '10 - 13 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '2 - 3 yrs',
#  '0 - 3 yrs']

# %%
skills=[]
for job in jobs:
    skills1=job.find('span',class_='srp-skills').text
    skills.append(skills1.strip())

# %%
skills
# Out:
# ['sas  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist',
#  'sas  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist',
#  'it tools  ,  tableau  ,  java  ,  vba  ,  data scientist  ,  statistical modeling  ,  visual basic',
#  'data analysis  ,  program management  ,  dashboards  ,  tableau  ,  use cases  ,  data scientist',
#  'information technology  ,  business process  ,  data science  ,  predictive modeling  ,  data scientist  ,  statistical modeling',
#  'data mining  ,  mobile  ,  business analysis  ,  sql  ,  predictive modeling  ,  data scientist  ,  text mining  ,  statistical analysis',
#  'visualization  ,  bi  ,  dashboards  ,  data science  ,  data scientist  ,  statistical modeling  ,  consulting  ,  predictive analytics  ,  tableau',
#  'data mining  ,  linear regression  ,  sql  ,  data science  ,  data scientist  ,  cluster analysis  ,  logistic regression  ,  sas  ,  consulting  ,  predictive analytics  ,  vba',
#  'data analysis  ,  data analytics  ,  sas  ,  data mining  ,  product roadmap  ,  sql  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist',
#  'time series analysis  ,  signal processing  ,  data science  ,  data scientist  ,  statistical modeling  ,  text mining  ,  data analysis  ,  statistical analysis',
#  'time series analysis  ,  linear regression  ,  data science  ,  data scientist  ,  logistic regression  ,  image processing  ,  advanced analytics  ,  factor analysis',
#  'docker  ,  git  ,  data structures  ,  python  ,  machine learning',
#  'algorithms  ,  python  ,  data mining  ,  machine learning  ,  mysql',
#  'data visualization  ,   statistical testing  ,   regression  ,   machine learning techniques',
#  'hive  ,  algorithms  ,  data mining  ,  sql  ,  hadoop  ,  big data  ,  python  ,  natural language processing  ,  machine learning',
#  'ds  ,  big data  ,  python  ,  oracle  ,  mining  ,  dsp  ,  bi  ,  storage  ,  sql  ,  database  ,  hadoop  ,  crm  ,  mobile  ,  machine learning',
#  'algorithms  ,  data mining  ,  database  ,  python  ,  mining  ,  machine learning',
#  'image processing  ,  algorithms  ,  natural language processing  ,  machine learning  ,  sql  ,  hadoop  ,  big data',
#  'algorithms  ,  c    ,  ensemble  ,  ds  ,  security  ,  hadoop  ,  press  ,  big data  ,  mongodb  ,  python  ,  machine learning  ,  nosql  ,  neo4j',
#  'hive  ,  algorithms  ,  data mining  ,  sql  ,  pig  ,  d3.js  ,  mongodb  ,  hbase  ,  python  ,  businessobjects  ,  problem solving  ,  machine learning  ,  nosql  ,  artificial neural networks  ,  cassandra',
#  'python  ,  data mining  ,  machine learning  ,  sql  ,  nosql  ,  leadership skills  ,  big data',
#  'information technology  ,  ssrs  ,  python  ,  data mining  ,  bi  ,  sql coding  ,  hadoop  ,  problem solving  ,  team player',
#  'information technology  ,  ssrs  ,  python  ,  data mining  ,  bi  ,  sql coding  ,  hadoop  ,  problem solving  ,  team player',
#  'information technology  ,  ssrs  ,  python  ,  data mining  ,  bi  ,  sql coding  ,  hadoop  ,  problem solving  ,  team player',
#  'information technology  ,  ssrs  ,  python  ,  data mining  ,  bi  ,  sql coding  ,  hadoop  ,  problem solving  ,  team player']

# %%
description=[]
for job in jobs:
    des=job.find('ul',class_='list-job-dtl clearfix')
    des1=des.li.text.replace('Job Description:','')
    
    
    description.append(des1.strip())

# %%
description
# Out:
# ['Data ScientistData Scientist RefreshmintGurgaon INR 4 - 9 LPA Experience : 1 - 3 YRS. Openings: 1Details:Do you feel passionately about solving problems through data? Have you... More Details',
#  'This Role Is Best Suited ForPerson with 3  years of experience in data science. The person should have prior experience with practical data science applications and use cases.... More Details',
#  'Use SAP ,  Tableau and Success Factors IT tools to derive insights from dataApply statistical knowledge to develop data modelsBuild Excel workbooks  ( including VBA ) Prepare ... More Details',
#  'Involve in the residency class room sessions to facilitate lectures and lab sessionsBe the first point contact for participants for academic queries and manage discussion grou... More Details',
#  'Data Scientist  Delhi NCR  ( 4  years of experience ) Data Scientist  Delhi NCR  ( 4  years of experience )  A Client of Analytics VidhyaGurugram INR 12 - 17 LPA Experience : ... More Details',
#  'The data scientist is responsible for solving complex big-data problems in the mobile space using data mining ,  machine learning ,  statistical analysis and common sense. The... More Details',
#  'The Data Scientist will support our business leads ,  business analysts and data engineers on data ,  analytics and BI initiatives and will ensure the delivery of actionable a... More Details',
#  'Data Scientist- Noida  ( 1-3 Years Of Experience ) Data Scientist- Noida  ( 1-3 Years Of Experience )  A Client of Analytics VidhyaNoida INR 4 - 8 LPA Experience : 1 - 3 YRS. ... More Details',
#  'Requirements: You have expertise in exploratory data analysis and visualisation  ( e.g. with SQL ,  Python / Pandas ,  R ,  or similar ) .You love using data to answer high-le... More Details',
#  'Data Scientist for GurgaonJob ID IT JOBS#258Location: Gurgaon ,  IndiaRequired Skills: Our client is seeking a creative Data Scientist to explore unstructured data from divers... More Details',
#  'Be an Individual Contributor in the Analytics Research and Development team and solve real-world problems using cutting-edge capabilities and emerging technologies. Be a part ... More Details',
#  'About Crowe Data ScienceEverything we do is about making the future of human work more purposeful. We do this by leveraging state-of-the-art machine learning ,  modern archite... More Details',
#  'Data ScientistData Scientist A Client of Analytics VidhyaGurgaon INR 10 - 15 LPA Experience : 2 - 4 YRS. Openings: 3Details:About the companyStarted 5 years ago ,  today it is... More Details',
#  'Position description: The purpose of this role is to closely work with business to identify and implement predictive models for healthcare.Primary Responsibilities:Model for r... More Details',
#  'As a Data Scientist at ElectrifAi ,  you will be part of a global team of data scientists working on products and solutions for Fortune 500 companies. You will improve upon an... More Details',
#  'Data ScientistData Scientist Dollarbird Information Services Pvt ,  Ltd.mysuru INR 5 - 10 LPA Experience : 5 - 15 YRS. Openings: 3Details:DollarBird is looking to add a Data S... More Details',
#  'Sentieo is powering the future of financial and corporate research in a $30B market. Our vision is to create a world where competitive organizations have the insights they nee... More Details',
#  'What do we do at BluePi: BluePi is a born in cloud organization with one of the main focus area being Big Data and Analytics. At BluePi we solve different business problems fo... More Details',
#  'Description If you want to forecast Indias eCommerce demand within 3 PERCENT  margin ,  build consumer models and scores for 50 million online shoppers ,  or decide the locati... More Details',
#  'Data ScientistData Scientist A Client of Analytics VidhyaDelhi ,  Gurugram INR 1 - 2 LPA Experience : 2 - 5 YRS. Openings: 1Details:The ideal candidate is adept at using large... More Details',
#  'Data Scientist We are searching for a Lead Data Scientist to lead our technical team and help us gain useful insights from heaps of raw data.Your responsibilities as a Data Sc... More Details',
#  'Job TitleData ScientistJob Description Integrated Analytics Team  Data ScientistOverviewIntegrated Analytics has pioneered a transaction based revenue methodology to inform an... More Details',
#  'Job TitleData ScientistOverviewIntegrated Analytics has pioneered a transaction based revenue methodology to inform and guide Mastercards Strategy ,  Product Design and Innova... More Details',
#  'Job TitleData ScientistOverviewIntegrated Analytics has pioneered a transaction based revenue methodology to inform and guide Mastercards Strategy ,  Product Design and Innova... More Details',
#  'Job TitleData ScientistJob Description Integrated Analytics Team  Data ScientistOverviewIntegrated Analytics has pioneered a transaction based revenue methodology to inform an... More Details']

# %%
link=[]
for job in jobs:
    link1=job.header.h2.a['href']
    link.append(link1)

# %%
link
# Out:
# ['https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-2-to-5-yrs-jobid-__PLUS__9fUKEl86gVzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-3-to-6-yrs-jobid-Gyey__SLASH__gl1a8VzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-3-to-5-yrs-jobid-TlT0NWDfbJVzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-great-learning-gurgaon-bengaluru-bangalore-0-to-3-yrs-jobid-Wz6vKSRSCSBzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-delhi-delhi-ncr-4-to-7-yrs-jobid-gWGyDgWz__SLASH__sRzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-dOjrEM65C1hzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-3-to-6-yrs-jobid-Tvz__SLASH__jV__SLASH__Gu__SLASH__RzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-noida-greater-noida-4-to-7-yrs-jobid-JIPyIjNZeRhzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-3-to-10-yrs-jobid-VBNr4BG3rlZzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-itforte-staffing-services-private-ltd-gurgaon-3-to-6-yrs-jobid-G4VBLWGbn__PLUS__NzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-axmiyan-hr-solutions-private-limited-gurgaon-3-to-6-yrs-jobid-bhvvbAc0__SLASH__9lzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-crowe-llp-noida-greater-noida-0-to-4-yrs-jobid-6u29fKNGPFJzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-vyPC6__PLUS__jFjShzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-team-computers-pvt-ltd-delhi-delhi-ncr-0-to-3-yrs-jobid-__SLASH__z4fKcGSLF9zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-electrifai-noida-greater-noida-10-to-13-yrs-jobid-kfKxWlEVstZzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-wa6D609KC__PLUS__VzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-sentieo-delhi-delhi-ncr-0-to-3-yrs-jobid-7YBNAKR__PLUS__4qxzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-beno-staffing-gurgaon-2-to-5-yrs-jobid-XEnXG2jbkv9zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-2-to-7-yrs-jobid-gp__PLUS__zUSe369BzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-delhi-delhi-ncr-2-to-5-yrs-jobid-y2p7OXYH5sNzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-pattem-digital-technologies-hyderabad-secunderabad-noida-greater-noida-chennai-bengaluru-bangalore-0-to-3-yrs-jobid-o9xBj2TNtZpzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-mastercard-gurgaon-2-to-3-yrs-jobid-uX__PLUS__NqqaHtlZzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-mastercard-gurgaon-2-to-3-yrs-jobid-1fiB34KLNu5zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-mastercard-gurgaon-2-to-3-yrs-jobid-VxOgvrmG__SLASH__bZzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-scientist-mastercard-gurgaon-0-to-3-yrs-jobid-PkbfeT2rOBpzpSvf__PLUS__uAgZw==&source=srp']

# %%
published_date=[]
for job in jobs:
    published_date1=job.find('span',class_='sim-posted').text
    published_date.append(published_date1.strip())

# %%
published_date
# Out:
# ['Posted 1 day ago',
#  'Posted 2 days ago',
#  'Posted 1 day ago',
#  'Posted few days ago',
#  'Posted 1 day ago',
#  'Posted 1 day ago',
#  'Posted 6 days ago',
#  'Posted 1 day ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 1 day ago',
#  'Posted 1 day ago',
#  'Posted 2 days ago',
#  'Posted few days ago',
#  'Posted 1 day ago',
#  'Posted few days ago',
#  'Posted 2 days ago',
#  'Posted 1 day ago',
#  'Posted 1 day ago',
#  'Posted few days ago',
#  'Posted 6 days ago',
#  'Posted 6 days ago',
#  'Posted 6 days ago',
#  'Posted 6 days ago']

# %%
data_tuples = list(zip(company,year_of_experience,description,skills,link))

# %%
data_tuples
# Out:
# [('Analytics Vidhya',
#   '2 - 5 yrs',
#   'Data ScientistData Scientist RefreshmintGurgaon INR 4 - 9 LPA Experience : 1 - 3 YRS. Openings: 1Details:Do you feel passionately about solving problems through data? Have you... More Details',
#   'sas  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-2-to-5-yrs-jobid-__PLUS__9fUKEl86gVzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '3 - 6 yrs',
#   'This Role Is Best Suited ForPerson with 3  years of experience in data science. The person should have prior experience with practical data science applications and use cases.... More Details',
#   'sas  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-3-to-6-yrs-jobid-Gyey__SLASH__gl1a8VzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '3 - 5 yrs',
#   'Use SAP ,  Tableau and Success Factors IT tools to derive insights from dataApply statistical knowledge to develop data modelsBuild Excel workbooks  ( including VBA ) Prepare ... More Details',
#   'it tools  ,  tableau  ,  java  ,  vba  ,  data scientist  ,  statistical modeling  ,  visual basic',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-3-to-5-yrs-jobid-TlT0NWDfbJVzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Great Learning',
#   '0 - 3 yrs',
#   'Involve in the residency class room sessions to facilitate lectures and lab sessionsBe the first point contact for participants for academic queries and manage discussion grou... More Details',
#   'data analysis  ,  program management  ,  dashboards  ,  tableau  ,  use cases  ,  data scientist',
#   'https://www.timesjobs.com/job-detail/data-scientist-great-learning-gurgaon-bengaluru-bangalore-0-to-3-yrs-jobid-Wz6vKSRSCSBzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '4 - 7 yrs',
#   'Data Scientist  Delhi NCR  ( 4  years of experience ) Data Scientist  Delhi NCR  ( 4  years of experience )  A Client of Analytics VidhyaGurugram INR 12 - 17 LPA Experience : ... More Details',
#   'information technology  ,  business process  ,  data science  ,  predictive modeling  ,  data scientist  ,  statistical modeling',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-delhi-delhi-ncr-4-to-7-yrs-jobid-gWGyDgWz__SLASH__sRzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '5 - 8 yrs',
#   'The data scientist is responsible for solving complex big-data problems in the mobile space using data mining ,  machine learning ,  statistical analysis and common sense. The... More Details',
#   'data mining  ,  mobile  ,  business analysis  ,  sql  ,  predictive modeling  ,  data scientist  ,  text mining  ,  statistical analysis',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-dOjrEM65C1hzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '3 - 6 yrs',
#   'The Data Scientist will support our business leads ,  business analysts and data engineers on data ,  analytics and BI initiatives and will ensure the delivery of actionable a... More Details',
#   'visualization  ,  bi  ,  dashboards  ,  data science  ,  data scientist  ,  statistical modeling  ,  consulting  ,  predictive analytics  ,  tableau',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-3-to-6-yrs-jobid-Tvz__SLASH__jV__SLASH__Gu__SLASH__RzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '4 - 7 yrs',
#   'Data Scientist- Noida  ( 1-3 Years Of Experience ) Data Scientist- Noida  ( 1-3 Years Of Experience )  A Client of Analytics VidhyaNoida INR 4 - 8 LPA Experience : 1 - 3 YRS. ... More Details',
#   'data mining  ,  linear regression  ,  sql  ,  data science  ,  data scientist  ,  cluster analysis  ,  logistic regression  ,  sas  ,  consulting  ,  predictive analytics  ,  vba',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-noida-greater-noida-4-to-7-yrs-jobid-JIPyIjNZeRhzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '3 - 10 yrs',
#   'Requirements: You have expertise in exploratory data analysis and visualisation  ( e.g. with SQL ,  Python / Pandas ,  R ,  or similar ) .You love using data to answer high-le... More Details',
#   'data analysis  ,  data analytics  ,  sas  ,  data mining  ,  product roadmap  ,  sql  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-3-to-10-yrs-jobid-VBNr4BG3rlZzpSvf__PLUS__uAgZw==&source=srp'),
#  ('ITFORTE STAFFING SERVICES PRIVATE LTD',
#   '3 - 6 yrs',
#   'Data Scientist for GurgaonJob ID IT JOBS#258Location: Gurgaon ,  IndiaRequired Skills: Our client is seeking a creative Data Scientist to explore unstructured data from divers... More Details',
#   'time series analysis  ,  signal processing  ,  data science  ,  data scientist  ,  statistical modeling  ,  text mining  ,  data analysis  ,  statistical analysis',
#   'https://www.timesjobs.com/job-detail/data-scientist-itforte-staffing-services-private-ltd-gurgaon-3-to-6-yrs-jobid-G4VBLWGbn__PLUS__NzpSvf__PLUS__uAgZw==&source=srp'),
#  ('axmiyan hr solutions private limited',
#   '3 - 6 yrs',
#   'Be an Individual Contributor in the Analytics Research and Development team and solve real-world problems using cutting-edge capabilities and emerging technologies. Be a part ... More Details',
#   'time series analysis  ,  linear regression  ,  data science  ,  data scientist  ,  logistic regression  ,  image processing  ,  advanced analytics  ,  factor analysis',
#   'https://www.timesjobs.com/job-detail/data-scientist-axmiyan-hr-solutions-private-limited-gurgaon-3-to-6-yrs-jobid-bhvvbAc0__SLASH__9lzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Crowe LLP',
#   '0 - 4 yrs',
#   'About Crowe Data ScienceEverything we do is about making the future of human work more purposeful. We do this by leveraging state-of-the-art machine learning ,  modern archite... More Details',
#   'docker  ,  git  ,  data structures  ,  python  ,  machine learning',
#   'https://www.timesjobs.com/job-detail/data-scientist-crowe-llp-noida-greater-noida-0-to-4-yrs-jobid-6u29fKNGPFJzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '5 - 8 yrs',
#   'Data ScientistData Scientist A Client of Analytics VidhyaGurgaon INR 10 - 15 LPA Experience : 2 - 4 YRS. Openings: 3Details:About the companyStarted 5 years ago ,  today it is... More Details',
#   'algorithms  ,  python  ,  data mining  ,  machine learning  ,  mysql',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-vyPC6__PLUS__jFjShzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Team Computers Pvt Ltd',
#   '0 - 3 yrs',
#   'Position description: The purpose of this role is to closely work with business to identify and implement predictive models for healthcare.Primary Responsibilities:Model for r... More Details',
#   'data visualization  ,   statistical testing  ,   regression  ,   machine learning techniques',
#   'https://www.timesjobs.com/job-detail/data-scientist-team-computers-pvt-ltd-delhi-delhi-ncr-0-to-3-yrs-jobid-__SLASH__z4fKcGSLF9zpSvf__PLUS__uAgZw==&source=srp'),
#  ('electrifai',
#   '10 - 13 yrs',
#   'As a Data Scientist at ElectrifAi ,  you will be part of a global team of data scientists working on products and solutions for Fortune 500 companies. You will improve upon an... More Details',
#   'hive  ,  algorithms  ,  data mining  ,  sql  ,  hadoop  ,  big data  ,  python  ,  natural language processing  ,  machine learning',
#   'https://www.timesjobs.com/job-detail/data-scientist-electrifai-noida-greater-noida-10-to-13-yrs-jobid-kfKxWlEVstZzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '5 - 8 yrs',
#   'Data ScientistData Scientist Dollarbird Information Services Pvt ,  Ltd.mysuru INR 5 - 10 LPA Experience : 5 - 15 YRS. Openings: 3Details:DollarBird is looking to add a Data S... More Details',
#   'ds  ,  big data  ,  python  ,  oracle  ,  mining  ,  dsp  ,  bi  ,  storage  ,  sql  ,  database  ,  hadoop  ,  crm  ,  mobile  ,  machine learning',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-5-to-8-yrs-jobid-wa6D609KC__PLUS__VzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Sentieo',
#   '0 - 3 yrs',
#   'Sentieo is powering the future of financial and corporate research in a $30B market. Our vision is to create a world where competitive organizations have the insights they nee... More Details',
#   'algorithms  ,  data mining  ,  database  ,  python  ,  mining  ,  machine learning',
#   'https://www.timesjobs.com/job-detail/data-scientist-sentieo-delhi-delhi-ncr-0-to-3-yrs-jobid-7YBNAKR__PLUS__4qxzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Beno Staffing',
#   '2 - 5 yrs',
#   'What do we do at BluePi: BluePi is a born in cloud organization with one of the main focus area being Big Data and Analytics. At BluePi we solve different business problems fo... More Details',
#   'image processing  ,  algorithms  ,  natural language processing  ,  machine learning  ,  sql  ,  hadoop  ,  big data',
#   'https://www.timesjobs.com/job-detail/data-scientist-beno-staffing-gurgaon-2-to-5-yrs-jobid-XEnXG2jbkv9zpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '2 - 7 yrs',
#   'Description If you want to forecast Indias eCommerce demand within 3 PERCENT  margin ,  build consumer models and scores for 50 million online shoppers ,  or decide the locati... More Details',
#   'algorithms  ,  c    ,  ensemble  ,  ds  ,  security  ,  hadoop  ,  press  ,  big data  ,  mongodb  ,  python  ,  machine learning  ,  nosql  ,  neo4j',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-2-to-7-yrs-jobid-gp__PLUS__zUSe369BzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '2 - 5 yrs',
#   'Data ScientistData Scientist A Client of Analytics VidhyaDelhi ,  Gurugram INR 1 - 2 LPA Experience : 2 - 5 YRS. Openings: 1Details:The ideal candidate is adept at using large... More Details',
#   'hive  ,  algorithms  ,  data mining  ,  sql  ,  pig  ,  d3.js  ,  mongodb  ,  hbase  ,  python  ,  businessobjects  ,  problem solving  ,  machine learning  ,  nosql  ,  artificial neural networks  ,  cassandra',
#   'https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-gurgaon-delhi-delhi-ncr-2-to-5-yrs-jobid-y2p7OXYH5sNzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Pattem Digital Technologies',
#   '0 - 3 yrs',
#   'Data Scientist We are searching for a Lead Data Scientist to lead our technical team and help us gain useful insights from heaps of raw data.Your responsibilities as a Data Sc... More Details',
#   'python  ,  data mining  ,  machine learning  ,  sql  ,  nosql  ,  leadership skills  ,  big data',
#   'https://www.timesjobs.com/job-detail/data-scientist-pattem-digital-technologies-hyderabad-secunderabad-noida-greater-noida-chennai-bengaluru-bangalore-0-to-3-yrs-jobid-o9xBj2TNtZpzpSvf__PLUS__uAgZw==&source=srp'),
#  ('MASTERCARD',
#   '2 - 3 yrs',
#   'Job TitleData ScientistJob Description Integrated Analytics Team  Data ScientistOverviewIntegrated Analytics has pioneered a transaction based revenue methodology to inform an... More Details',
#   'information technology  ,  ssrs  ,  python  ,  data mining  ,  bi  ,  sql coding  ,  hadoop  ,  problem solving  ,  team player',
#   'https://www.timesjobs.com/job-detail/data-scientist-mastercard-gurgaon-2-to-3-yrs-jobid-uX__PLUS__NqqaHtlZzpSvf__PLUS__uAgZw==&source=srp'),
#  ('MASTERCARD',
#   '2 - 3 yrs',
#   'Job TitleData ScientistOverviewIntegrated Analytics has pioneered a transaction based revenue methodology to inform and guide Mastercards Strategy ,  Product Design and Innova... More Details',
#   'information technology  ,  ssrs  ,  python  ,  data mining  ,  bi  ,  sql coding  ,  hadoop  ,  problem solving  ,  team player',
#   'https://www.timesjobs.com/job-detail/data-scientist-mastercard-gurgaon-2-to-3-yrs-jobid-1fiB34KLNu5zpSvf__PLUS__uAgZw==&source=srp'),
#  ('MASTERCARD',
#   '2 - 3 yrs',
#   'Job TitleData ScientistOverviewIntegrated Analytics has pioneered a transaction based revenue methodology to inform and guide Mastercards Strategy ,  Product Design and Innova... More Details',
#   'information technology  ,  ssrs  ,  python  ,  data mining  ,  bi  ,  sql coding  ,  hadoop  ,  problem solving  ,  team player',
#   'https://www.timesjobs.com/job-detail/data-scientist-mastercard-gurgaon-2-to-3-yrs-jobid-VxOgvrmG__SLASH__bZzpSvf__PLUS__uAgZw==&source=srp'),
#  ('MASTERCARD',
#   '0 - 3 yrs',
#   'Job TitleData ScientistJob Description Integrated Analytics Team  Data ScientistOverviewIntegrated Analytics has pioneered a transaction based revenue methodology to inform an... More Details',
#   'information technology  ,  ssrs  ,  python  ,  data mining  ,  bi  ,  sql coding  ,  hadoop  ,  problem solving  ,  team player',
#   'https://www.timesjobs.com/job-detail/data-scientist-mastercard-gurgaon-0-to-3-yrs-jobid-PkbfeT2rOBpzpSvf__PLUS__uAgZw==&source=srp')]

# %%
 df=pd.DataFrame(data_tuples, columns=['company','year_of_experience','description','skills','link'])

# %%
df.to_csv(r' dataScientist.csv')

# %%
df
# Out:
#                                   company year_of_experience  \
# 0                        Analytics Vidhya          2 - 5 yrs
# 1                        Analytics Vidhya          3 - 6 yrs
# 2                        Analytics Vidhya          3 - 5 yrs
# 3                          Great Learning          0 - 3 yrs
# 4                        Analytics Vidhya          4 - 7 yrs
# 5                        Analytics Vidhya          5 - 8 yrs
# 6                        Analytics Vidhya          3 - 6 yrs
# 7                        Analytics Vidhya          4 - 7 yrs
# 8                        Analytics Vidhya         3 - 10 yrs
# 9   ITFORTE STAFFING SERVICES PRIVATE LTD          3 - 6 yrs
# 10   axmiyan hr solutions private limited          3 - 6 yrs
# 11                              Crowe LLP          0 - 4 yrs
# 12                       Analytics Vidhya          5 - 8 yrs
# 13                 Team Computers Pvt Ltd          0 - 3 yrs
# 14                             electrifai        10 - 13 yrs
# 15                       Analytics Vidhya          5 - 8 yrs
# 16                                Sentieo          0 - 3 yrs
# 17                          Beno Staffing          2 - 5 yrs
# 18                       Analytics Vidhya          2 - 7 yrs
# 19                       Analytics Vidhya          2 - 5 yrs
# 20            Pattem Digital Technologies          0 - 3 yrs
# 21                             MASTERCARD          2 - 3 yrs
# 22                             MASTERCARD          2 - 3 yrs
# 23                             MASTERCARD          2 - 3 yrs
# 24                             MASTERCARD          0 - 3 yrs
#
#                                           description  \
# 0   Data ScientistData Scientist RefreshmintGurgao...
# 1   This Role Is Best Suited ForPerson with 3  yea...
# 2   Use SAP ,  Tableau and Success Factors IT tool...
# 3   Involve in the residency class room sessions t...
# 4   Data Scientist  Delhi NCR  ( 4  years of exper...
# 5   The data scientist is responsible for solving ...
# 6   The Data Scientist will support our business l...
# 7   Data Scientist- Noida  ( 1-3 Years Of Experien...
# 8   Requirements: You have expertise in explorator...
# 9   Data Scientist for GurgaonJob ID IT JOBS#258Lo...
# 10  Be an Individual Contributor in the Analytics ...
# 11  About Crowe Data ScienceEverything we do is ab...
# 12  Data ScientistData Scientist A Client of Analy...
# 13  Position description: The purpose of this role...
# 14  As a Data Scientist at ElectrifAi ,  you will ...
# 15  Data ScientistData Scientist Dollarbird Inform...
# 16  Sentieo is powering the future of financial an...
# 17  What do we do at BluePi: BluePi is a born in c...
# 18  Description If you want to forecast Indias eCo...
# 19  Data ScientistData Scientist A Client of Analy...
# 20  Data Scientist We are searching for a Lead Dat...
# 21  Job TitleData ScientistJob Description Integra...
# 22  Job TitleData ScientistOverviewIntegrated Anal...
# 23  Job TitleData ScientistOverviewIntegrated Anal...
# 24  Job TitleData ScientistJob Description Integra...
#
#                                                skills  \
# 0   sas  ,  data science  ,  use cases  ,  predict...
# 1   sas  ,  data science  ,  use cases  ,  predict...
# 2   it tools  ,  tableau  ,  java  ,  vba  ,  data...
# 3   data analysis  ,  program management  ,  dashb...
# 4   information technology  ,  business process  ,...
# 5   data mining  ,  mobile  ,  business analysis  ...
# 6   visualization  ,  bi  ,  dashboards  ,  data s...
# 7   data mining  ,  linear regression  ,  sql  ,  ...
# 8   data analysis  ,  data analytics  ,  sas  ,  d...
# 9   time series analysis  ,  signal processing  , ...
# 10  time series analysis  ,  linear regression  , ...
# 11  docker  ,  git  ,  data structures  ,  python ...
# 12  algorithms  ,  python  ,  data mining  ,  mach...
# 13  data visualization  ,   statistical testing  ,...
# 14  hive  ,  algorithms  ,  data mining  ,  sql  ,...
# 15  ds  ,  big data  ,  python  ,  oracle  ,  mini...
# 16  algorithms  ,  data mining  ,  database  ,  py...
# 17  image processing  ,  algorithms  ,  natural la...
# 18  algorithms  ,  c    ,  ensemble  ,  ds  ,  sec...
# 19  hive  ,  algorithms  ,  data mining  ,  sql  ,...
# 20  python  ,  data mining  ,  machine learning  ,...
# 21  information technology  ,  ssrs  ,  python  , ...
# 22  information technology  ,  ssrs  ,  python  , ...
# 23  information technology  ,  ssrs  ,  python  , ...
# 24  information technology  ,  ssrs  ,  python  , ...
#
#                                                  link
# 0   https://www.timesjobs.com/job-detail/data-scie...
# 1   https://www.timesjobs.com/job-detail/data-scie...
# 2   https://www.timesjobs.com/job-detail/data-scie...
# 3   https://www.timesjobs.com/job-detail/data-scie...
# 4   https://www.timesjobs.com/job-detail/data-scie...
# 5   https://www.timesjobs.com/job-detail/data-scie...
# 6   https://www.timesjobs.com/job-detail/data-scie...
# 7   https://www.timesjobs.com/job-detail/data-scie...
# 8   https://www.timesjobs.com/job-detail/data-scie...
# 9   https://www.timesjobs.com/job-detail/data-scie...
# 10  https://www.timesjobs.com/job-detail/data-scie...
# 11  https://www.timesjobs.com/job-detail/data-scie...
# 12  https://www.timesjobs.com/job-detail/data-scie...
# 13  https://www.timesjobs.com/job-detail/data-scie...
# 14  https://www.timesjobs.com/job-detail/data-scie...
# 15  https://www.timesjobs.com/job-detail/data-scie...
# 16  https://www.timesjobs.com/job-detail/data-scie...
# 17  https://www.timesjobs.com/job-detail/data-scie...
# 18  https://www.timesjobs.com/job-detail/data-scie...
# 19  https://www.timesjobs.com/job-detail/data-scie...
# 20  https://www.timesjobs.com/job-detail/data-scie...
# 21  https://www.timesjobs.com/job-detail/data-scie...
# 22  https://www.timesjobs.com/job-detail/data-scie...
# 23  https://www.timesjobs.com/job-detail/data-scie...
# 24  https://www.timesjobs.com/job-detail/data-scie...
