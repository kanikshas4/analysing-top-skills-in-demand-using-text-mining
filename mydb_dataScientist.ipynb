# %%
import pandas as pd
data = pd.read_csv (r' dataScientist.csv')   
df = pd.DataFrame(data, columns= ['company','year_of_experience','description','skills'])
df
# Out:
#                                   company year_of_experience  \
# 0                        Analytics Vidhya          2 - 5 yrs
# 1                        Analytics Vidhya          3 - 6 yrs
# 2                        Analytics Vidhya          3 - 5 yrs
# 3                          Great Learning          0 - 3 yrs
# 4                        Analytics Vidhya          4 - 7 yrs
# 5                        Analytics Vidhya          5 - 8 yrs
# 6                        Analytics Vidhya          3 - 6 yrs
# 7                        Analytics Vidhya          4 - 7 yrs
# 8                        Analytics Vidhya         3 - 10 yrs
# 9   ITFORTE STAFFING SERVICES PRIVATE LTD          3 - 6 yrs
# 10   axmiyan hr solutions private limited          3 - 6 yrs
# 11                              Crowe LLP          0 - 4 yrs
# 12                       Analytics Vidhya          5 - 8 yrs
# 13                 Team Computers Pvt Ltd          0 - 3 yrs
# ...

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  passwd="apple123"
)
print(mydb)

# %%
mycursor = mydb.cursor()

# %%
mycursor.execute('SHOW DATABASES')

# %%
for datab in mycursor:
    print(datab)
# Out:
# ('information_schema',)
# ('mydb',)
# ('mysql',)
# ('performance_schema',)
# ('python_db',)
# ('sys',)

# %%
mycursor.execute('USE mydb')

# %%
mycursor.execute("CREATE TABLE mydata_table (company VARCHAR(255),year_of_experience VARCHAR(255),description VARCHAR(255),skills VARCHAR(255))")

# %%
for i,row in df.iterrows():
            sql = "INSERT INTO mydb.mydata_table VALUES (%s,%s,%s,%s)"
            mycursor.execute(sql, tuple(row))
            print("Record inserted")
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %%
# Execute query
sql = "SELECT * FROM mydata_table "
mycursor.execute(sql)

# Fetch all the records
result = mycursor.fetchall()
for i in result:
    print(i)
# Out:
# ('Analytics Vidhya', '2 - 5 yrs', 'Data ScientistData Scientist RefreshmintGurgaon INR 4 - 9 LPA Experience : 1 - 3 YRS. Openings: 1Details:Do you feel passionately about solving problems through data? Have you... More Details', 'sas  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist')
# ('Analytics Vidhya', '3 - 6 yrs', 'This Role Is Best Suited ForPerson with 3  years of experience in data science. The person should have prior experience with practical data science applications and use cases.... More Details', 'sas  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist')
# ('Analytics Vidhya', '3 - 5 yrs', 'Use SAP ,  Tableau and Success Factors IT tools to derive insights from dataApply statistical knowledge to develop data modelsBuild Excel workbooks  ( including VBA ) Prepare ... More Details', 'it tools  ,  tableau  ,  java  ,  vba  ,  data scientist  ,  statistical modeling  ,  visual basic')
# ...

# %%
import sqlalchemy
engine = sqlalchemy.create_engine('mysql://root:apple123@127.0.0.1') # connect to server

engine.execute("USE mydb")

# %%
# Insert whole DataFrame into MySQL
df.to_sql('mydata_table', con = engine, if_exists = 'append', chunksize = 1000,index=False)

# %%
# Execute query
sql = "SELECT * FROM mydata_table"
mycursor.execute(sql)
# Fetch all the records
result = mycursor.fetchall()
for i in result:
    print(i)
# Out:
# ('Analytics Vidhya', '2 - 5 yrs', 'Data ScientistData Scientist RefreshmintGurgaon INR 4 - 9 LPA Experience : 1 - 3 YRS. Openings: 1Details:Do you feel passionately about solving problems through data? Have you... More Details', 'sas  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist')
# ('Analytics Vidhya', '3 - 6 yrs', 'This Role Is Best Suited ForPerson with 3  years of experience in data science. The person should have prior experience with practical data science applications and use cases.... More Details', 'sas  ,  data science  ,  use cases  ,  predictive modeling  ,  data scientist')
# ('Analytics Vidhya', '3 - 5 yrs', 'Use SAP ,  Tableau and Success Factors IT tools to derive insights from dataApply statistical knowledge to develop data modelsBuild Excel workbooks  ( including VBA ) Prepare ... More Details', 'it tools  ,  tableau  ,  java  ,  vba  ,  data scientist  ,  statistical modeling  ,  visual basic')
# ...

# %%
# Close the connection
if (mydb.is_connected()):
    mycursor.close()
    mydb.close()
