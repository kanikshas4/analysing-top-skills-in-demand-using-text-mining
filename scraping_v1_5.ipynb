# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

URL = ("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Machine+Learning+Engineer&txtLocation=Delhi")
#conducting a request of the stated URL above:
page3 = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup( page3.text, "html.parser")

# %%
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

# %%
for job in jobs:
    company=[]
    company1= job.find('h3',class_ ='joblist-comp-name')
    company.append(company1.text.strip())

# %%
print(company)
# Out:
# ['B.S.B International Career Pvt. Ltd.\r\n     (More Jobs)']

# %%
company=[]
for job in jobs:
    company1= job.find('h3',class_ ='joblist-comp-name')
    company.append(company1.text.strip())

# %%
print(company)
# Out:
# ['JobsLo Consultants', 'Smart Joules', 'APPLYCUP HIRING SOLUTIONS LLP', 'Analytics Vidhya', 'Analytics Vidhya', 'Analytics Vidhya', 'EXPEDIA', 'EXPEDIA', 'Shelby Management Solutions', 'Paxcom India  ( P )  Ltd', 'McKinsey Global Services', 'NLP People', 'thework.life\r\n     (More Jobs)', 'thework.life\r\n     (More Jobs)', 'thework.life\r\n     (More Jobs)', 'thework.life\r\n     (More Jobs)', 'thework.life\r\n     (More Jobs)', 'thework.life\r\n     (More Jobs)', 'thework.life\r\n     (More Jobs)', 'thework.life\r\n     (More Jobs)', 'Electrobrain modern technologies pvt ltd\r\n     (More Jobs)', 'SHIVA PLACEMENTS\r\n     (More Jobs)', 'Vishi Soni\r\n     (More Jobs)', 'Mayank consultancy\r\n     (More Jobs)', 'B.S.B International Career Pvt. Ltd.\r\n     (More Jobs)']

# %%
year_of_experience =[]
for job in jobs:
    years=job.find('ul', class_='top-jd-dtl clearfix')
    for years in jobs:
        year=years.find('li').text.replace('card_travel','')
        
        year_of_experience.append(year.strip())

# %%
year_of_experience
# Out:
# ['0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs',
#  '0 - 1 yrs',
#  '3 - 6 yrs',
#  '5 - 8 yrs',
#  '3 - 6 yrs',
#  '4 - 7 yrs',
#  '6 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '7 - 12 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '3 - 8 yrs',
#  '2 - 4 yrs',
#  '2 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '4 - 6 yrs',
#  '1 - 5 yrs',
#  '3 - 8 yrs',
#  '4 - 7 yrs',
#  '3 - 8 yrs',
#  '3 - 8 yrs',
#  '8 - 12 yrs',
#  '1 - 6 yrs']

# %%
skills=[]
for job in jobs:
    skills1=job.find('span',class_='srp-skills').text
    skills.append(skills1.strip())

# %%
skills
# Out:
# ['python  ,  data mining  ,  information retrieval  ,  machine learning  ,  logical thinking  ,  sql',
#  'algorithms  ,  python  ,  communication engineering  ,  machine learning  ,  infrastructure  ,  hadoop  ,  big data',
#  'algorithms  ,  python  ,  machine learning  ,  linux  ,  web development  ,  opencv',
#  'hive  ,  scala  ,  pig  ,  java  ,  hadoop  ,  mongodb  ,  python  ,  algorithm development  ,  mining  ,  machine learning  ,  nosql  ,  mapreduce  ,  cassandra',
#  'algorithms  ,  data mining  ,  artificial intelligence  ,  sql  ,  python  ,  information retrieval  ,  mobile  ,  machine learning  ,  application support',
#  'algorithms  ,  python  ,  scala  ,  machine learning  ,  nosql  ,  java  ,  cassandra  ,  written communication  ,  hdfs  ,  cloud computing  ,  big data',
#  'hive  ,  algorithms  ,  scala  ,  sql  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python  ,  cloud services  ,  machine learning  ,  system architecture  ,  ooad',
#  'hive  ,  algorithms  ,  scala  ,  sql  ,  software engineering  ,  hadoop  ,  python  ,  cloud services  ,  machine learning  ,  nosql  ,  system architecture  ,  ooad',
#  'python  ,  machine learning  ,  sql  ,  devops  ,  data structures  ,  object oriented programming  ,  api  ,  software developer',
#  'data mining  ,  artificial intelligence  ,  docker  ,  java  ,  postgresql  ,  pattern recognition  ,  python  ,  machine learning',
#  'hosting  ,  sql  ,  oops  ,  mysql  ,  python  ,  machine learning  ,  django  ,  infrastructure  ,  dash',
#  'algorithms  ,  information technology  ,  data mining  ,  sql  ,  d3.js  ,  python  ,  problem solving  ,  machine learning  ,  entry level',
#  'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#  'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#  'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#  'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#  'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#  'Version Control  ,  Continuous Integration Servers  ,  Configuration Management  ,  Deployment automation  ,  Infrastructure Orchestration  ,  Network Protocols',
#  'Version Control  ,  Continuous Integration Servers  ,  Configuration Management  ,  Deployment automation  ,  Infrastructure Orchestration  ,  Network Protocols',
#  'Version Control  ,  Continuous Integration Servers  ,  Configuration Management  ,  Deployment automation  ,  Infrastructure Orchestration  ,  Network Protocols',
#  'VMware  ,  Automation  ,  Perl  ,  Incident management  ,  Service Management  ,  PHP  ,  DHCP  ,  Microsoft .net',
#  'Lead  ,  Engineer Mechanical',
#  'Forging  ,  Flanges  ,  Body-Bonnet  ,  Casting  ,  Machining  ,  EIL  ,  Well Known Forge  ,  Forge  ,  IBR',
#  'Chemical Plant Maintenance  ,  Power Plant Supervising  ,  Plant Room Operations  ,  Product Engineering  ,  Collection Process',
#  'Hardware  ,  Networking']

# %%
description=[]
for job in jobs:
    des=job.find('ul',class_='list-job-dtl clearfix')
    des1=des.li.text.replace('Job Description:','')
    
    
    description.append(des1.strip())

# %%
description
# Out:
# ['We are looking for a Data Scientist that will help us discover the information hidden in vast amounts of data ,  and help us make smarter decisions to deliver even better prod... More Details',
#  'Responsibilities : Exploring and visualizing data to gain an understanding of it ,  then identifying differences in data distribution that could affect performance when deploy... More Details',
#  'Qualification : BE  , Btech  , BSC Computer / IT , MSC  , MCA , any graduate ,  Experience : 5 - 8 YearsSkills : TensorFlow or Keras ,  python ,  visualizingJob Description :J... More Details',
#  'Machine Learning engineer- Delhi / NCR  ( 3  Years Of Experience ) Machine Learning engineer- Delhi / NCR  ( 3  Years Of Experience )  A Client of Analytics VidhyaGurgaon INR ... More Details',
#  'Machine Learning Engineer- Gurugram  ( 4  Years of Experience ) Machine Learning Engineer- Gurugram  ( 4  Years of Experience )  A Client of Analytics VidhyaGurugram INR 15 - ... More Details',
#  'Responsibilities:Build creative ,  reliable and scalable machine learning and analytics platform in an agile software development environmentContinually evolve the platform as... More Details',
#  'We are looking for a Machine Learning Engineer to join our Machine Learning Engineering team in Gurgaon. Our team works very closely with Data Scientists in a fast paced Agile... More Details',
#  'Are you fascinated by data and building robust data pipelines which process massive amounts of data at scale and speed to provide crucial insights to the end customer? This is... More Details',
#  'Job DescriptionRoles and ResponsibilitiesObject Oriented Programming - MandatoryData Structures - MandatorySQL - MandatoryPython - MandatoryBasic Stats - MandatoryML Framework... More Details',
#  'In this position ,  the AI / ML Specialist will work with stakeholders and technical team members to deliver capabilities through agile acquisition ,  by lever... More Details',
#  'Bachelors or masters degree in computer science ,  engineering ,  applied math ,  quantitative social sciences or related field 2-4 years of professional work experience with ... More Details',
#  'Overview Responsibilities :- Selecting features ,  building and optimizing classifiers using machine learning techniques.- Data mining using state-of-the-art methods.- Extendi... More Details',
#  'Job Responsibilities:Responsible for the development of a responsive ,  high-quality web-based user interface using React.js.Work with the product teams and its engineers to d... More Details',
#  'Job Responsibilities:Responsible for the development of a responsive ,  high-quality web-based user interface using React.js.Work with the product teams and its engineers to d... More Details',
#  'Job Responsibilities:Develops information systems by designing ,  developing ,  and installing software solutions.determines operational feasibility by evaluating analysis ,  ... More Details',
#  'Job Responsibilities:Develops information systems by designing ,  developing ,  and installing software solutions.determines operational feasibility by evaluating analysis ,  ... More Details',
#  'Job Responsibilities:Develops information systems by designing ,  developing ,  and installing software solutions.determines operational feasibility by evaluating analysis ,  ... More Details',
#  'JOB DESCRIPTION:devops engineer in noida Responsibilities:Version Control using GIT.Monitoring ,  Logging  &  Alerting using Elastic-Search ,  Logstash and Kibana  ( ELK )  an... More Details',
#  'Responsibilities:building and setting up new development tools and infrastructureunderstanding the needs of stakeholders and conveying this to developersworking on ways to aut... More Details',
#  'Responsibilities:building and setting up new development tools and infrastructureunderstanding the needs of stakeholders and conveying this to developersworking on ways to aut... More Details',
#  'ResponsibilitiesYour ResponsibilitiesHelp solve technically complex ,  strategic / high-profile or long-running customer cases that may require interaction with Software Engin... More Details',
#  'Manufacturing Engineer Job Duties:Evaluates manufacturing processes by designing and conducting research programs; applying knowledge of product design ,  fabrication ,  assem... More Details',
#  'We require candidates for sales and marketing for a well-known forge ,  IBR ,  EIL certified firm in Ghaziabad ,  Uttar Pradesh. The candidate has to make quotations ,  Order ... More Details',
#  'Determines engineering requirements by conducting inspections and analytical tests; analyzing and synthesizing data; maintaining control charts; determining root causes; prepa... More Details',
#  'A passion forsolving problems and providing workable solutionsKnowledge of algorithms and data structuresStrong analytical and reasoning skills with an ability to visualise pr... More Details']

# %%
link=[]
for job in jobs:
    link1=job.header.h2.a['href']
    link.append(link1)

# %%
link
# Out:
# ['https://www.timesjobs.com/job-detail/machine-learning-engineer-jobslo-consultants-noida-greater-noida-0-to-1-yrs-jobid-hDFZk5Wx1H9zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-smart-joules-delhi-3-to-6-yrs-jobid-6iwaz7HvMYdzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-5-to-8-yrs-jobid-8vJTI8EfbdFzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-analytics-vidhya-gurgaon-delhi-delhi-ncr-3-to-6-yrs-jobid-uECiNNXv8ndzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-analytics-vidhya-gurgaon-4-to-7-yrs-jobid-gPqycPLjxeVzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-analytics-vidhya-gurgaon-6-to-8-yrs-jobid-ZXlOysRH0qRzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-ii-expedia-gurgaon-0-to-3-yrs-jobid-M7TWvfbwFSFzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-iii-expedia-gurgaon-0-to-3-yrs-jobid-X__PLUS__gzo__SLASH__fkJ81zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-shelby-management-solutions-delhi-delhi-ncr-jaipur-bengaluru-bangalore-7-to-12-yrs-jobid-d6bXPSpY8qFzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-paxcom-india-p-ltd-delhi-delhi-ncr-2-to-5-yrs-jobid-1TA8cVF__SLASH__RmxzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/machine-learning-engineer-ops-digital-assets-mckinsey-global-services-gurgaon-2-to-4-yrs-jobid-BGJbNjQxeU5zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/deep-learning-engineer-nlp-artificial-intelligence-machine-learning-nlp-people-delhi-5-to-8-yrs-jobid-BlI2vSce7vRzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/software-engineer-thework-life-faridabad-3-to-8-yrs-jobid-DCf4mOLcg1JzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/software-engineer-thework-life-ghaziabad-2-to-4-yrs-jobid-vZNqdG41__SLASH__FlzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/software-engineer-thework-life-noida-greater-noida-2-to-7-yrs-jobid-6CufdNp27z5zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/software-engineer-thework-life-gurgaon-3-to-8-yrs-jobid-__SLASH__52SIe086DpzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/software-engineer-thework-life-delhi-3-to-8-yrs-jobid-lvhvDlBJnfJzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/devops-engineer-thework-life-noida-greater-noida-4-to-6-yrs-jobid-xCKpxDKwxZBzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/devops-engineer-thework-life-gurgaon-1-to-5-yrs-jobid-Q__SLASH__V7HqgzirlzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/devops-engineer-thework-life-delhi-3-to-8-yrs-jobid-uiS3znFzvbRzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/support-escalation-engineer-electrobrain-modern-technologies-pvt-ltd-bengaluru-bangalore-chennai-delhi-ncr-gurgaon-hyderabad-secunderabad-4-to-7-yrs-jobid-xMxLoxept9RzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/manufacturing-analyst-shiva-placements-ahmedabad-bengaluru-bangalore-chennai-delhi-ncr-mumbai-3-to-8-yrs-jobid-riK__PLUS__ZOsMbh1zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/sales-co-ordinator-sales-executive-marketing-executive-marketing-vishi-soni-delhi-ncr-3-to-8-yrs-jobid-WypzEiRtlWhzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/chemical-plant-operator-engineer-assistant-engineer-assistant-oil-and-gas-company-delhi-kolkata-mumbai-noida-greater-noida-warangal-8-to-12-yrs-jobid-Vo0UpbpdJj9zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/software-engineer-b-s-b-international-career-pvt-ltd-bengaluru-bangalore-delhi-ncr-hyderabad-secunderabad-kolkata-mumbai-1-to-6-yrs-jobid-Hi8NKrdAg5RzpSvf__PLUS__uAgZw==&source=srp']

# %%
published_date=[]
for job in jobs:
    published_date1=job.find('span',class_='sim-posted').text
    published_date.append(published_date1.strip())

# %%
published_date
# Out:
# ['Posted 6 days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 6 days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 1 day ago',
#  'Posted today',
#  'Posted 1 day ago']

# %%
data_tuples = list(zip(company,year_of_experience,description,skills,link))

# %%
data_tuples
# Out:
# [('JobsLo Consultants',
#   '0 - 1 yrs',
#   'We are looking for a Data Scientist that will help us discover the information hidden in vast amounts of data ,  and help us make smarter decisions to deliver even better prod... More Details',
#   'python  ,  data mining  ,  information retrieval  ,  machine learning  ,  logical thinking  ,  sql',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-jobslo-consultants-noida-greater-noida-0-to-1-yrs-jobid-hDFZk5Wx1H9zpSvf__PLUS__uAgZw==&source=srp'),
#  ('Smart Joules',
#   '3 - 6 yrs',
#   'Responsibilities : Exploring and visualizing data to gain an understanding of it ,  then identifying differences in data distribution that could affect performance when deploy... More Details',
#   'algorithms  ,  python  ,  communication engineering  ,  machine learning  ,  infrastructure  ,  hadoop  ,  big data',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-smart-joules-delhi-3-to-6-yrs-jobid-6iwaz7HvMYdzpSvf__PLUS__uAgZw==&source=srp'),
#  ('APPLYCUP HIRING SOLUTIONS LLP',
#   '5 - 8 yrs',
#   'Qualification : BE  , Btech  , BSC Computer / IT , MSC  , MCA , any graduate ,  Experience : 5 - 8 YearsSkills : TensorFlow or Keras ,  python ,  visualizingJob Description :J... More Details',
#   'algorithms  ,  python  ,  machine learning  ,  linux  ,  web development  ,  opencv',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-5-to-8-yrs-jobid-8vJTI8EfbdFzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '3 - 6 yrs',
#   'Machine Learning engineer- Delhi / NCR  ( 3  Years Of Experience ) Machine Learning engineer- Delhi / NCR  ( 3  Years Of Experience )  A Client of Analytics VidhyaGurgaon INR ... More Details',
#   'hive  ,  scala  ,  pig  ,  java  ,  hadoop  ,  mongodb  ,  python  ,  algorithm development  ,  mining  ,  machine learning  ,  nosql  ,  mapreduce  ,  cassandra',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-analytics-vidhya-gurgaon-delhi-delhi-ncr-3-to-6-yrs-jobid-uECiNNXv8ndzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '4 - 7 yrs',
#   'Machine Learning Engineer- Gurugram  ( 4  Years of Experience ) Machine Learning Engineer- Gurugram  ( 4  Years of Experience )  A Client of Analytics VidhyaGurugram INR 15 - ... More Details',
#   'algorithms  ,  data mining  ,  artificial intelligence  ,  sql  ,  python  ,  information retrieval  ,  mobile  ,  machine learning  ,  application support',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-analytics-vidhya-gurgaon-4-to-7-yrs-jobid-gPqycPLjxeVzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '6 - 8 yrs',
#   'Responsibilities:Build creative ,  reliable and scalable machine learning and analytics platform in an agile software development environmentContinually evolve the platform as... More Details',
#   'algorithms  ,  python  ,  scala  ,  machine learning  ,  nosql  ,  java  ,  cassandra  ,  written communication  ,  hdfs  ,  cloud computing  ,  big data',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-analytics-vidhya-gurgaon-6-to-8-yrs-jobid-ZXlOysRH0qRzpSvf__PLUS__uAgZw==&source=srp'),
#  ('EXPEDIA',
#   '0 - 3 yrs',
#   'We are looking for a Machine Learning Engineer to join our Machine Learning Engineering team in Gurgaon. Our team works very closely with Data Scientists in a fast paced Agile... More Details',
#   'hive  ,  algorithms  ,  scala  ,  sql  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python  ,  cloud services  ,  machine learning  ,  system architecture  ,  ooad',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-ii-expedia-gurgaon-0-to-3-yrs-jobid-M7TWvfbwFSFzpSvf__PLUS__uAgZw==&source=srp'),
#  ('EXPEDIA',
#   '0 - 3 yrs',
#   'Are you fascinated by data and building robust data pipelines which process massive amounts of data at scale and speed to provide crucial insights to the end customer? This is... More Details',
#   'hive  ,  algorithms  ,  scala  ,  sql  ,  software engineering  ,  hadoop  ,  python  ,  cloud services  ,  machine learning  ,  nosql  ,  system architecture  ,  ooad',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-iii-expedia-gurgaon-0-to-3-yrs-jobid-X__PLUS__gzo__SLASH__fkJ81zpSvf__PLUS__uAgZw==&source=srp'),
#  ('Shelby Management Solutions',
#   '7 - 12 yrs',
#   'Job DescriptionRoles and ResponsibilitiesObject Oriented Programming - MandatoryData Structures - MandatorySQL - MandatoryPython - MandatoryBasic Stats - MandatoryML Framework... More Details',
#   'python  ,  machine learning  ,  sql  ,  devops  ,  data structures  ,  object oriented programming  ,  api  ,  software developer',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-shelby-management-solutions-delhi-delhi-ncr-jaipur-bengaluru-bangalore-7-to-12-yrs-jobid-d6bXPSpY8qFzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Paxcom India  ( P )  Ltd',
#   '2 - 5 yrs',
#   'In this position ,  the AI / ML Specialist will work with stakeholders and technical team members to deliver capabilities through agile acquisition ,  by lever... More Details',
#   'data mining  ,  artificial intelligence  ,  docker  ,  java  ,  postgresql  ,  pattern recognition  ,  python  ,  machine learning',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-paxcom-india-p-ltd-delhi-delhi-ncr-2-to-5-yrs-jobid-1TA8cVF__SLASH__RmxzpSvf__PLUS__uAgZw==&source=srp'),
#  ('McKinsey Global Services',
#   '2 - 4 yrs',
#   'Bachelors or masters degree in computer science ,  engineering ,  applied math ,  quantitative social sciences or related field 2-4 years of professional work experience with ... More Details',
#   'hosting  ,  sql  ,  oops  ,  mysql  ,  python  ,  machine learning  ,  django  ,  infrastructure  ,  dash',
#   'https://www.timesjobs.com/job-detail/machine-learning-engineer-ops-digital-assets-mckinsey-global-services-gurgaon-2-to-4-yrs-jobid-BGJbNjQxeU5zpSvf__PLUS__uAgZw==&source=srp'),
#  ('NLP People',
#   '5 - 8 yrs',
#   'Overview Responsibilities :- Selecting features ,  building and optimizing classifiers using machine learning techniques.- Data mining using state-of-the-art methods.- Extendi... More Details',
#   'algorithms  ,  information technology  ,  data mining  ,  sql  ,  d3.js  ,  python  ,  problem solving  ,  machine learning  ,  entry level',
#   'https://www.timesjobs.com/job-detail/deep-learning-engineer-nlp-artificial-intelligence-machine-learning-nlp-people-delhi-5-to-8-yrs-jobid-BlI2vSce7vRzpSvf__PLUS__uAgZw==&source=srp'),
#  ('thework.life\r\n     (More Jobs)',
#   '3 - 8 yrs',
#   'Job Responsibilities:Responsible for the development of a responsive ,  high-quality web-based user interface using React.js.Work with the product teams and its engineers to d... More Details',
#   'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#   'https://www.timesjobs.com/job-detail/software-engineer-thework-life-faridabad-3-to-8-yrs-jobid-DCf4mOLcg1JzpSvf__PLUS__uAgZw==&source=srp'),
#  ('thework.life\r\n     (More Jobs)',
#   '2 - 4 yrs',
#   'Job Responsibilities:Responsible for the development of a responsive ,  high-quality web-based user interface using React.js.Work with the product teams and its engineers to d... More Details',
#   'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#   'https://www.timesjobs.com/job-detail/software-engineer-thework-life-ghaziabad-2-to-4-yrs-jobid-vZNqdG41__SLASH__FlzpSvf__PLUS__uAgZw==&source=srp'),
#  ('thework.life\r\n     (More Jobs)',
#   '2 - 7 yrs',
#   'Job Responsibilities:Develops information systems by designing ,  developing ,  and installing software solutions.determines operational feasibility by evaluating analysis ,  ... More Details',
#   'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#   'https://www.timesjobs.com/job-detail/software-engineer-thework-life-noida-greater-noida-2-to-7-yrs-jobid-6CufdNp27z5zpSvf__PLUS__uAgZw==&source=srp'),
#  ('thework.life\r\n     (More Jobs)',
#   '3 - 8 yrs',
#   'Job Responsibilities:Develops information systems by designing ,  developing ,  and installing software solutions.determines operational feasibility by evaluating analysis ,  ... More Details',
#   'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#   'https://www.timesjobs.com/job-detail/software-engineer-thework-life-gurgaon-3-to-8-yrs-jobid-__SLASH__52SIe086DpzpSvf__PLUS__uAgZw==&source=srp'),
#  ('thework.life\r\n     (More Jobs)',
#   '3 - 8 yrs',
#   'Job Responsibilities:Develops information systems by designing ,  developing ,  and installing software solutions.determines operational feasibility by evaluating analysis ,  ... More Details',
#   'Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net c#  ,  Logical Thinking  ,  Communication skills  ,  software development',
#   'https://www.timesjobs.com/job-detail/software-engineer-thework-life-delhi-3-to-8-yrs-jobid-lvhvDlBJnfJzpSvf__PLUS__uAgZw==&source=srp'),
#  ('thework.life\r\n     (More Jobs)',
#   '4 - 6 yrs',
#   'JOB DESCRIPTION:devops engineer in noida Responsibilities:Version Control using GIT.Monitoring ,  Logging  &  Alerting using Elastic-Search ,  Logstash and Kibana  ( ELK )  an... More Details',
#   'Version Control  ,  Continuous Integration Servers  ,  Configuration Management  ,  Deployment automation  ,  Infrastructure Orchestration  ,  Network Protocols',
#   'https://www.timesjobs.com/job-detail/devops-engineer-thework-life-noida-greater-noida-4-to-6-yrs-jobid-xCKpxDKwxZBzpSvf__PLUS__uAgZw==&source=srp'),
#  ('thework.life\r\n     (More Jobs)',
#   '1 - 5 yrs',
#   'Responsibilities:building and setting up new development tools and infrastructureunderstanding the needs of stakeholders and conveying this to developersworking on ways to aut... More Details',
#   'Version Control  ,  Continuous Integration Servers  ,  Configuration Management  ,  Deployment automation  ,  Infrastructure Orchestration  ,  Network Protocols',
#   'https://www.timesjobs.com/job-detail/devops-engineer-thework-life-gurgaon-1-to-5-yrs-jobid-Q__SLASH__V7HqgzirlzpSvf__PLUS__uAgZw==&source=srp'),
#  ('thework.life\r\n     (More Jobs)',
#   '3 - 8 yrs',
#   'Responsibilities:building and setting up new development tools and infrastructureunderstanding the needs of stakeholders and conveying this to developersworking on ways to aut... More Details',
#   'Version Control  ,  Continuous Integration Servers  ,  Configuration Management  ,  Deployment automation  ,  Infrastructure Orchestration  ,  Network Protocols',
#   'https://www.timesjobs.com/job-detail/devops-engineer-thework-life-delhi-3-to-8-yrs-jobid-uiS3znFzvbRzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Electrobrain modern technologies pvt ltd\r\n     (More Jobs)',
#   '4 - 7 yrs',
#   'ResponsibilitiesYour ResponsibilitiesHelp solve technically complex ,  strategic / high-profile or long-running customer cases that may require interaction with Software Engin... More Details',
#   'VMware  ,  Automation  ,  Perl  ,  Incident management  ,  Service Management  ,  PHP  ,  DHCP  ,  Microsoft .net',
#   'https://www.timesjobs.com/job-detail/support-escalation-engineer-electrobrain-modern-technologies-pvt-ltd-bengaluru-bangalore-chennai-delhi-ncr-gurgaon-hyderabad-secunderabad-4-to-7-yrs-jobid-xMxLoxept9RzpSvf__PLUS__uAgZw==&source=srp'),
#  ('SHIVA PLACEMENTS\r\n     (More Jobs)',
#   '3 - 8 yrs',
#   'Manufacturing Engineer Job Duties:Evaluates manufacturing processes by designing and conducting research programs; applying knowledge of product design ,  fabrication ,  assem... More Details',
#   'Lead  ,  Engineer Mechanical',
#   'https://www.timesjobs.com/job-detail/manufacturing-analyst-shiva-placements-ahmedabad-bengaluru-bangalore-chennai-delhi-ncr-mumbai-3-to-8-yrs-jobid-riK__PLUS__ZOsMbh1zpSvf__PLUS__uAgZw==&source=srp'),
#  ('Vishi Soni\r\n     (More Jobs)',
#   '3 - 8 yrs',
#   'We require candidates for sales and marketing for a well-known forge ,  IBR ,  EIL certified firm in Ghaziabad ,  Uttar Pradesh. The candidate has to make quotations ,  Order ... More Details',
#   'Forging  ,  Flanges  ,  Body-Bonnet  ,  Casting  ,  Machining  ,  EIL  ,  Well Known Forge  ,  Forge  ,  IBR',
#   'https://www.timesjobs.com/job-detail/sales-co-ordinator-sales-executive-marketing-executive-marketing-vishi-soni-delhi-ncr-3-to-8-yrs-jobid-WypzEiRtlWhzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Mayank consultancy\r\n     (More Jobs)',
#   '8 - 12 yrs',
#   'Determines engineering requirements by conducting inspections and analytical tests; analyzing and synthesizing data; maintaining control charts; determining root causes; prepa... More Details',
#   'Chemical Plant Maintenance  ,  Power Plant Supervising  ,  Plant Room Operations  ,  Product Engineering  ,  Collection Process',
#   'https://www.timesjobs.com/job-detail/chemical-plant-operator-engineer-assistant-engineer-assistant-oil-and-gas-company-delhi-kolkata-mumbai-noida-greater-noida-warangal-8-to-12-yrs-jobid-Vo0UpbpdJj9zpSvf__PLUS__uAgZw==&source=srp'),
#  ('B.S.B International Career Pvt. Ltd.\r\n     (More Jobs)',
#   '1 - 6 yrs',
#   'A passion forsolving problems and providing workable solutionsKnowledge of algorithms and data structuresStrong analytical and reasoning skills with an ability to visualise pr... More Details',
#   'Hardware  ,  Networking',
#   'https://www.timesjobs.com/job-detail/software-engineer-b-s-b-international-career-pvt-ltd-bengaluru-bangalore-delhi-ncr-hyderabad-secunderabad-kolkata-mumbai-1-to-6-yrs-jobid-Hi8NKrdAg5RzpSvf__PLUS__uAgZw==&source=srp')]

# %%
 df=pd.DataFrame(data_tuples, columns=['company','year_of_experience','description','skills','link'])

# %%
df.to_csv(r'ML_Engineer.csv')

# %%
df
# Out:
#                                               company year_of_experience  \
# 0                                  JobsLo Consultants          0 - 1 yrs
# 1                                        Smart Joules          3 - 6 yrs
# 2                       APPLYCUP HIRING SOLUTIONS LLP          5 - 8 yrs
# 3                                    Analytics Vidhya          3 - 6 yrs
# 4                                    Analytics Vidhya          4 - 7 yrs
# 5                                    Analytics Vidhya          6 - 8 yrs
# 6                                             EXPEDIA          0 - 3 yrs
# 7                                             EXPEDIA          0 - 3 yrs
# 8                         Shelby Management Solutions         7 - 12 yrs
# 9                            Paxcom India  ( P )  Ltd          2 - 5 yrs
# 10                           McKinsey Global Services          2 - 4 yrs
# 11                                         NLP People          5 - 8 yrs
# 12                   thework.life\r\n     (More Jobs)          3 - 8 yrs
# 13                   thework.life\r\n     (More Jobs)          2 - 4 yrs
# 14                   thework.life\r\n     (More Jobs)          2 - 7 yrs
# 15                   thework.life\r\n     (More Jobs)          3 - 8 yrs
# 16                   thework.life\r\n     (More Jobs)          3 - 8 yrs
# 17                   thework.life\r\n     (More Jobs)          4 - 6 yrs
# 18                   thework.life\r\n     (More Jobs)          1 - 5 yrs
# 19                   thework.life\r\n     (More Jobs)          3 - 8 yrs
# 20  Electrobrain modern technologies pvt ltd\r\n  ...          4 - 7 yrs
# 21               SHIVA PLACEMENTS\r\n     (More Jobs)          3 - 8 yrs
# 22                     Vishi Soni\r\n     (More Jobs)          3 - 8 yrs
# 23             Mayank consultancy\r\n     (More Jobs)         8 - 12 yrs
# 24  B.S.B International Career Pvt. Ltd.\r\n     (...          1 - 6 yrs
#
#                                           description  \
# 0   We are looking for a Data Scientist that will ...
# 1   Responsibilities : Exploring and visualizing d...
# 2   Qualification : BE  , Btech  , BSC Computer / ...
# 3   Machine Learning engineer- Delhi / NCR  ( 3  Y...
# 4   Machine Learning Engineer- Gurugram  ( 4  Year...
# 5   Responsibilities:Build creative ,  reliable an...
# 6   We are looking for a Machine Learning Engineer...
# 7   Are you fascinated by data and building robust...
# 8   Job DescriptionRoles and ResponsibilitiesObjec...
# 9   In this position ,  the AI / ML Specialist wil...
# 10  Bachelors or masters degree in computer scienc...
# 11  Overview Responsibilities :- Selecting feature...
# 12  Job Responsibilities:Responsible for the devel...
# 13  Job Responsibilities:Responsible for the devel...
# 14  Job Responsibilities:Develops information syst...
# 15  Job Responsibilities:Develops information syst...
# 16  Job Responsibilities:Develops information syst...
# 17  JOB DESCRIPTION:devops engineer in noida Respo...
# 18  Responsibilities:building and setting up new d...
# 19  Responsibilities:building and setting up new d...
# 20  ResponsibilitiesYour ResponsibilitiesHelp solv...
# 21  Manufacturing Engineer Job Duties:Evaluates ma...
# 22  We require candidates for sales and marketing ...
# 23  Determines engineering requirements by conduct...
# 24  A passion forsolving problems and providing wo...
#
#                                                skills  \
# 0   python  ,  data mining  ,  information retriev...
# 1   algorithms  ,  python  ,  communication engine...
# 2   algorithms  ,  python  ,  machine learning  , ...
# 3   hive  ,  scala  ,  pig  ,  java  ,  hadoop  , ...
# 4   algorithms  ,  data mining  ,  artificial inte...
# 5   algorithms  ,  python  ,  scala  ,  machine le...
# 6   hive  ,  algorithms  ,  scala  ,  sql  ,  java...
# 7   hive  ,  algorithms  ,  scala  ,  sql  ,  soft...
# 8   python  ,  machine learning  ,  sql  ,  devops...
# 9   data mining  ,  artificial intelligence  ,  do...
# 10  hosting  ,  sql  ,  oops  ,  mysql  ,  python ...
# 11  algorithms  ,  information technology  ,  data...
# 12  Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net...
# 13  Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net...
# 14  Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net...
# 15  Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net...
# 16  Java  ,  Python  ,  mean  ,  Ruby  ,  ASP .net...
# 17  Version Control  ,  Continuous Integration Ser...
# 18  Version Control  ,  Continuous Integration Ser...
# 19  Version Control  ,  Continuous Integration Ser...
# 20  VMware  ,  Automation  ,  Perl  ,  Incident ma...
# 21                       Lead  ,  Engineer Mechanical
# 22  Forging  ,  Flanges  ,  Body-Bonnet  ,  Castin...
# 23  Chemical Plant Maintenance  ,  Power Plant Sup...
# 24                            Hardware  ,  Networking
#
#                                                  link
# 0   https://www.timesjobs.com/job-detail/machine-l...
# 1   https://www.timesjobs.com/job-detail/machine-l...
# 2   https://www.timesjobs.com/job-detail/machine-l...
# 3   https://www.timesjobs.com/job-detail/machine-l...
# 4   https://www.timesjobs.com/job-detail/machine-l...
# 5   https://www.timesjobs.com/job-detail/machine-l...
# 6   https://www.timesjobs.com/job-detail/machine-l...
# 7   https://www.timesjobs.com/job-detail/machine-l...
# 8   https://www.timesjobs.com/job-detail/machine-l...
# 9   https://www.timesjobs.com/job-detail/machine-l...
# 10  https://www.timesjobs.com/job-detail/machine-l...
# 11  https://www.timesjobs.com/job-detail/deep-lear...
# 12  https://www.timesjobs.com/job-detail/software-...
# 13  https://www.timesjobs.com/job-detail/software-...
# 14  https://www.timesjobs.com/job-detail/software-...
# 15  https://www.timesjobs.com/job-detail/software-...
# 16  https://www.timesjobs.com/job-detail/software-...
# 17  https://www.timesjobs.com/job-detail/devops-en...
# 18  https://www.timesjobs.com/job-detail/devops-en...
# 19  https://www.timesjobs.com/job-detail/devops-en...
# 20  https://www.timesjobs.com/job-detail/support-e...
# 21  https://www.timesjobs.com/job-detail/manufactu...
# 22  https://www.timesjobs.com/job-detail/sales-co-...
# 23  https://www.timesjobs.com/job-detail/chemical-...
# 24  https://www.timesjobs.com/job-detail/software-...
