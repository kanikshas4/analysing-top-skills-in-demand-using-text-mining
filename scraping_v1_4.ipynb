# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

URL = ("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Game+Developer&txtLocation=North+India ")
#conducting a request of the stated URL above:
page3 = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup( page3.text, "html.parser")

# %%
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

# %%
for job in jobs:
    company=[]
    company1= job.find('h3',class_ ='joblist-comp-name')
    company.append(company1.text.strip())

# %%
print(company)
# Out:
# ['APPLYCUP HIRING SOLUTIONS LLP']

# %%
company=[]
for job in jobs:
    company1= job.find('h3',class_ ='joblist-comp-name')
    company.append(company1.text.strip())

# %%
print(company)
# Out:
# ['NextDoor Global Services\r\n     (More Jobs)', 'SEVEN CONSULTANCY', 'APPLYCUP HIRING SOLUTIONS LLP', 'APPLYCUP HIRING SOLUTIONS LLP', 'ASPIRATION', 'TEAMPLUS STAFFING SOLUTION PVT. LTD.', 'Red Apple Technologies Pvt. Ltd.', 'SEVEN CONSULTANCY', 'APPLYCUP HIRING SOLUTIONS LLP', 'Fine Jobs Consultant Pvt. Ltd.', 'JobsLo Consultants', 'JobsLo Consultants', 'Miracle Studios', 'FresherMart', 'The NineHertz', 'StartxLabs', 'APPLYCUP HIRING SOLUTIONS LLP', 'APPLYCUP HIRING SOLUTIONS LLP', 'Smashing Geeks', 'Linkites Infotech Pvt Ltd', 'APPLYCUP HIRING SOLUTIONS LLP', 'APPLYCUP HIRING SOLUTIONS LLP']

# %%
year_of_experience =[]
for job in jobs:
    years=job.find('ul', class_='top-jd-dtl clearfix')
    for years in jobs:
        year=years.find('li').text.replace('card_travel','')
        
        year_of_experience.append(year.strip())

# %%
year_of_experience
# Out:
# ['3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '3 - 7 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '4 - 7 yrs',
#  '2 - 8 yrs',
#  '0 - 3 yrs',
#  '0 - 3 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '5 - 8 yrs',
#  '1 - 3 yrs',
#  '1 - 3 yrs',
#  '1 - 5 yrs',
#  '2 - 5 yrs',
#  '1 - 4 yrs',
#  '2 - 5 yrs',
#  '2 - 5 yrs',
#  '0 - 3 yrs',
#  '0 - 4 yrs',
#  '0 - 3 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs']

# %%
skills=[]
for job in jobs:
    skills1=job.find('span',class_='srp-skills').text
    skills.append(skills1.strip())

# %%
skills
# Out:
# ['game development  ,   programming languages   (  Java  ,   C  ,   etc  )    ,  Rendering  ,   3D animation  ,   physics  ,    ,  Mobile and console game development  ,   techniques  ,   best practices',
#  'Design  ,   architect  ,   test  ,  Generate game scripts',
#  'c    ,  database  ,  java  ,  oops  ,  php  ,  problem solving',
#  'mobile  ,  svn  ,  team player  ,  javascript  ,  jquery  ,  git  ,  written communication  ,  games  ,  angularjs',
#  'algorithms  ,  webworks  ,  games  ,  data structures',
#  'rest  ,  html5  ,  games  ,  html',
#  'c#  ,  algorithms  ,  c    ,  c  ,  c   programming  ,  symbian  ,  javascript  ,  j2me  ,  java  ,  games  ,  debugging  ,  data structures',
#  'product creation  ,  Deliver high quality  ,  Animate characters',
#  'Scripting  ,   Textures  ,   Animation  ,   GUI Styles',
#  'software development  ,  unity3d  ,  game development  ,  coding  ,  saas  ,  sockets',
#  'fundamentals  ,  java  ,  oops  ,  games  ,  sql',
#  'c#  ,  c    ,  windows  ,  visual studio  ,  java  ,  games  ,  debugging',
#  'turnaround  ,  vmc  ,  scheduling  ,  action  ,  documentation  ,  ideas  ,  maintenance',
#  'integrate game system  ,   develop 3D games  ,   execute UI',
#  'mobile  ,  game development  ,  scripting',
#  'c#  ,  c    ,  opengl  ,  visual studio  ,  debugging  ,  directx',
#  'oops  ,  games  ,  debugging  ,  windows',
#  'testing  ,  mobile  ,  writing  ,  gui',
#  'c    ,  c  ,  mobile  ,  problem solving  ,  graphics  ,  opengl  ,  javascript  ,  java',
#  'testing  ,  mobile  ,  writing  ,  gui',
#  'c#  ,  c    ,  wordpress  ,  augmented reality  ,  javascript  ,  android development  ,  java  ,  linux  ,  html  ,  data structures',
#  'c#  ,  c    ,  wordpress  ,  augmented reality  ,  javascript  ,  android development  ,  java  ,  linux  ,  html  ,  data structures']

# %%
description=[]
for job in jobs:
    des=job.find('ul',class_='list-job-dtl clearfix')
    des1=des.li.text.replace('Job Description:','')
    
    
    description.append(des1.strip())

# %%
description
# Out:
# ['Requirements: -     Proven working experience in full lifecycle game development     Hands on experience primarily with c ++ or other programming languages  ( Java ,  C ,  etc... More Details',
#  'JOB DETAILSDesign ,  architect ,  test and implement game features and framework ranging from tools ,  gameplay and AITake an active part in product creationMaintain and optim... More Details',
#  'Game DeveloperMohali ,  PunjQualification : BCA ,  B.Tech , B.Sc Experience : 0 - 3 YearsSkills : programming ,  game developmentJob Description :We are looking for B.Tech / B... More Details',
#  'Game DeveloperGurgaon ,  Delhi Qualification : Any Graduate Experience : 4 - 8 YearsSkills : AR ,  VR ,  Multiplayer ,  3DJob Description :1 ) . Minimum 4 year... More Details',
#  'Game Developer For A Leading OTT Platform Company A Leading OTT PlatformExperience 2 - 8 YearsLocation Bangalore ,  Delhi ,  MumbaiSalary Upto 20 LacPosition TitleGame Develop... More Details',
#  'Key Skills : game developer ,  wireframe ,  html ,  IOS ,  photon ,  game sparkJob Role  &  Responsibilities:Created cross-platform  ( Android /  Chrome etc. )  web applicatio... More Details',
#  'Excellent knowledge of C   programming language ,  Data structures and Algorithms ,  programming methodologies ,  etc.programming Knowledge in the relevant languages  ( Java ,... More Details',
#  'JOB DETAILSDesign ,  architect ,  test and implement game features and framework ranging from tools ,  gameplay and AITake an active part in product creationMaintain and optim... More Details',
#  'Unity Game DeveloperGurgaon ,  DelhiDate Posted : 25 / 05 / 2020 Qualification : BE  , Btech  , BSC Computer / IT , MSC  , MCA , any graduate ,  Experience : 2 - 5 YearsSkills... More Details',
#  'Job DescriptionWe are searching for Game Developers for our company who will operate remotely. Required skills: Ideal candidate must have experience of minimum 1.5 years Shoul... More Details',
#  'Job Description : 1 to 2 years experience in developing Android apps /  games Solid knowledge of Core Java and OOPS fundamentals Good knowledge of SQL A fighter with a strong ... More Details',
#  'Job Responsibilities : Consistently develop 3d game features of high-level quality ,  on several platforms ,  by gathering requirements ,  designing solutions ,  implementing ... More Details',
#  'Is this role right for me? To do this role ,  you will need to:be a team player and a leaderbe a very good Unity Developerbe approachable and listen to what people need and wa... More Details',
#  'Responsibilities:Design and develop tank mechanics and relevant upgrades.program and execute UI ,  menus ,  and functionalities.Monitor and integrate game system Plugin.design... More Details',
#  'Requirement: Experience: 1-4 YrNumber Of Position: 2Location: Jaipur Excellent knowledge of Unity ,  including experience with scripting ,  textures ,  animati... More Details',
#  'Game Developer  ( Unity / 3D )  Looking for passionate and reliable applicants to join our team! Candidate should have minimum 2-year exp in Unity game development.educational... More Details',
#  'Game Developer-Cocos2djsNoida ,  Uttar Pradesh Qualification : BCA ,  B.Tech , B.Sc Experience : 2 - 5 YearsSkills : it ,  computers ,  programmingJob Description :* Consisten... More Details',
#  'Unity Game Developer - Animation / c#Jaipur ,  Rajasthan Qualification : BCA ,  B.Tech , B.Sc Experience : 0 - 3 YearsSkills : programming ,  game development ,  BCA ,  BscJob... More Details',
#  'Unity 3D Game Developer Responsibilities:With strong Unity 3D programming skills ,  you will work closely with other engineers to implement core gameplay features in a hybrid ... More Details',
#  'SKILLSExcellent knowledge of Unity ,  including experience with scripting ,  textures ,  animation ,  GUI styles ,  and user session management.Familiarity with level design a... More Details',
#  'Game Developer - Unity 3D  ,  JavaScript  ,  HTML C  Jaipur ,  Rajasthan Qualification : BCA ,  B.Tech , B.Sc Experience : 1 - 6 YearsSkills : programming ,  BCA ,  BSC ,  ITJ... More Details',
#  'Game Developer - Unity 3D  ,  JavaScript  ,  HTML C  Delhi ,  Delhi Qualification : BCA ,  B.Tech , B.Sc Experience : 1 - 6 YearsSkills : programming ,  javascript ,  BCA ,  I... More Details']

# %%
link=[]
for job in jobs:
    link1=job.header.h2.a['href']
    link.append(link1)

# %%
link
# Out:
# ['https://www.timesjobs.com/job-detail/senior-game-developer-rhedfuel-studio-delhi-3-to-7-yrs-jobid-G1eOwHc8ojpzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-seven-consultancy-delhi-delhi-ncr-2-to-5-yrs-jobid-sX1GFNwLc9hzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-applycup-hiring-solutions-llp-mohali-0-to-3-yrs-jobid-H8Y1q0aVl35zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-4-to-7-yrs-jobid-LbQstiL7D3tzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-aspiration-mumbai-delhi-delhi-ncr-bengaluru-bangalore-2-to-8-yrs-jobid-q5F__PLUS__HxNFkvZzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-teamplus-staffing-solution-pvt-ltd-noida-greater-noida-0-to-3-yrs-jobid-cjAw0hYM__SLASH__qxzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-red-apple-technologies-pvt-ltd-delhi-delhi-ncr-kolkata-0-to-3-yrs-jobid-JyOHGi9GY4NzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-executive-seven-consultancy-delhi-delhi-ncr-2-to-5-yrs-jobid-SHB2eMZp5fpzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-game-developer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-2-to-5-yrs-jobid-l__PLUS__p6__PLUS__vgIynZzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-game-developer-fine-jobs-consultant-pvt-ltd-indore-5-to-8-yrs-jobid-ksCS0JI2nvNzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/android-game-developer-jobslo-consultants-noida-greater-noida-1-to-3-yrs-jobid-0__SLASH__c0MTiO0E9zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-game-developer-jobslo-consultants-noida-greater-noida-1-to-3-yrs-jobid-__PLUS__B06tI1GQEFzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-game-developer-miracle-studios-chandigarh-1-to-5-yrs-jobid-fCNS23xdWZFzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-game-developer-freshermart-jaipur-2-to-5-yrs-jobid-We4aMAKFWYBzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-game-developer-the-ninehertz-jaipur-1-to-4-yrs-jobid-jUPGdqgT2QRzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-unity-3d-startxlabs-delhi-delhi-ncr-2-to-5-yrs-jobid-__PLUS__1aXV3UDDpVzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-cocos2djs-applycup-hiring-solutions-llp-noida-greater-noida-2-to-5-yrs-jobid-NRONcjCaIzVzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-game-developer-animation-c-applycup-hiring-solutions-llp-jaipur-0-to-3-yrs-jobid-xCXwFJzUkuhzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-3d-game-developer-smashing-geeks-delhi-delhi-ncr-0-to-4-yrs-jobid-b27n1EOIGBxzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/unity-2d-3d-game-developer-linkites-infotech-pvt-ltd-indore-0-to-3-yrs-jobid-SoCfrYs05wVzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-unity-3d-javascript-html-c-applycup-hiring-solutions-llp-jaipur-1-to-6-yrs-jobid-M90O38Z3qsNzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/game-developer-unity-3d-javascript-html-c-applycup-hiring-solutions-llp-delhi-delhi-ncr-1-to-6-yrs-jobid-sEaoIw1tBFNzpSvf__PLUS__uAgZw==&source=srp']

# %%
published_date=[]
for job in jobs:
    published_date1=job.find('span',class_='sim-posted').text
    published_date.append(published_date1.strip())

# %%
published_date
# Out:
# ['Posted few days ago',
#  'Posted 3 days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 3 days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 4 days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 1 day ago',
#  'Posted few days ago',
#  'Posted few days ago']

# %%
data_tuples = list(zip(company,year_of_experience,description,skills,link))

# %%
data_tuples
# Out:
# [('NextDoor Global Services\r\n     (More Jobs)',
#   '3 - 7 yrs',
#   'Requirements: -     Proven working experience in full lifecycle game development     Hands on experience primarily with c ++ or other programming languages  ( Java ,  C ,  etc... More Details',
#   'game development  ,   programming languages   (  Java  ,   C  ,   etc  )    ,  Rendering  ,   3D animation  ,   physics  ,    ,  Mobile and console game development  ,   techniques  ,   best practices',
#   'https://www.timesjobs.com/job-detail/senior-game-developer-rhedfuel-studio-delhi-3-to-7-yrs-jobid-G1eOwHc8ojpzpSvf__PLUS__uAgZw==&source=srp'),
#  ('SEVEN CONSULTANCY',
#   '2 - 5 yrs',
#   'JOB DETAILSDesign ,  architect ,  test and implement game features and framework ranging from tools ,  gameplay and AITake an active part in product creationMaintain and optim... More Details',
#   'Design  ,   architect  ,   test  ,  Generate game scripts',
#   'https://www.timesjobs.com/job-detail/game-developer-seven-consultancy-delhi-delhi-ncr-2-to-5-yrs-jobid-sX1GFNwLc9hzpSvf__PLUS__uAgZw==&source=srp'),
#  ('APPLYCUP HIRING SOLUTIONS LLP',
#   '0 - 3 yrs',
#   'Game DeveloperMohali ,  PunjQualification : BCA ,  B.Tech , B.Sc Experience : 0 - 3 YearsSkills : programming ,  game developmentJob Description :We are looking for B.Tech / B... More Details',
#   'c    ,  database  ,  java  ,  oops  ,  php  ,  problem solving',
#   'https://www.timesjobs.com/job-detail/game-developer-applycup-hiring-solutions-llp-mohali-0-to-3-yrs-jobid-H8Y1q0aVl35zpSvf__PLUS__uAgZw==&source=srp'),
#  ('APPLYCUP HIRING SOLUTIONS LLP',
#   '4 - 7 yrs',
#   'Game DeveloperGurgaon ,  Delhi Qualification : Any Graduate Experience : 4 - 8 YearsSkills : AR ,  VR ,  Multiplayer ,  3DJob Description :1 ) . Minimum 4 year... More Details',
#   'mobile  ,  svn  ,  team player  ,  javascript  ,  jquery  ,  git  ,  written communication  ,  games  ,  angularjs',
#   'https://www.timesjobs.com/job-detail/game-developer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-4-to-7-yrs-jobid-LbQstiL7D3tzpSvf__PLUS__uAgZw==&source=srp'),
#  ('ASPIRATION',
#   '2 - 8 yrs',
#   'Game Developer For A Leading OTT Platform Company A Leading OTT PlatformExperience 2 - 8 YearsLocation Bangalore ,  Delhi ,  MumbaiSalary Upto 20 LacPosition TitleGame Develop... More Details',
#   'algorithms  ,  webworks  ,  games  ,  data structures',
#   'https://www.timesjobs.com/job-detail/game-developer-aspiration-mumbai-delhi-delhi-ncr-bengaluru-bangalore-2-to-8-yrs-jobid-q5F__PLUS__HxNFkvZzpSvf__PLUS__uAgZw==&source=srp'),
#  ('TEAMPLUS STAFFING SOLUTION PVT. LTD.',
#   '0 - 3 yrs',
#   'Key Skills : game developer ,  wireframe ,  html ,  IOS ,  photon ,  game sparkJob Role  &  Responsibilities:Created cross-platform  ( Android /  Chrome etc. )  web applicatio... More Details',
#   'rest  ,  html5  ,  games  ,  html',
#   'https://www.timesjobs.com/job-detail/game-developer-teamplus-staffing-solution-pvt-ltd-noida-greater-noida-0-to-3-yrs-jobid-cjAw0hYM__SLASH__qxzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Red Apple Technologies Pvt. Ltd.',
#   '0 - 3 yrs',
#   'Excellent knowledge of C   programming language ,  Data structures and Algorithms ,  programming methodologies ,  etc.programming Knowledge in the relevant languages  ( Java ,... More Details',
#   'c#  ,  algorithms  ,  c    ,  c  ,  c   programming  ,  symbian  ,  javascript  ,  j2me  ,  java  ,  games  ,  debugging  ,  data structures',
#   'https://www.timesjobs.com/job-detail/game-developer-red-apple-technologies-pvt-ltd-delhi-delhi-ncr-kolkata-0-to-3-yrs-jobid-JyOHGi9GY4NzpSvf__PLUS__uAgZw==&source=srp'),
#  ('SEVEN CONSULTANCY',
#   '2 - 5 yrs',
#   'JOB DETAILSDesign ,  architect ,  test and implement game features and framework ranging from tools ,  gameplay and AITake an active part in product creationMaintain and optim... More Details',
#   'product creation  ,  Deliver high quality  ,  Animate characters',
#   'https://www.timesjobs.com/job-detail/game-developer-executive-seven-consultancy-delhi-delhi-ncr-2-to-5-yrs-jobid-SHB2eMZp5fpzpSvf__PLUS__uAgZw==&source=srp'),
#  ('APPLYCUP HIRING SOLUTIONS LLP',
#   '2 - 5 yrs',
#   'Unity Game DeveloperGurgaon ,  DelhiDate Posted : 25 / 05 / 2020 Qualification : BE  , Btech  , BSC Computer / IT , MSC  , MCA , any graduate ,  Experience : 2 - 5 YearsSkills... More Details',
#   'Scripting  ,   Textures  ,   Animation  ,   GUI Styles',
#   'https://www.timesjobs.com/job-detail/unity-game-developer-applycup-hiring-solutions-llp-gurgaon-delhi-delhi-ncr-2-to-5-yrs-jobid-l__PLUS__p6__PLUS__vgIynZzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Fine Jobs Consultant Pvt. Ltd.',
#   '5 - 8 yrs',
#   'Job DescriptionWe are searching for Game Developers for our company who will operate remotely. Required skills: Ideal candidate must have experience of minimum 1.5 years Shoul... More Details',
#   'software development  ,  unity3d  ,  game development  ,  coding  ,  saas  ,  sockets',
#   'https://www.timesjobs.com/job-detail/unity-game-developer-fine-jobs-consultant-pvt-ltd-indore-5-to-8-yrs-jobid-ksCS0JI2nvNzpSvf__PLUS__uAgZw==&source=srp'),
#  ('JobsLo Consultants',
#   '1 - 3 yrs',
#   'Job Description : 1 to 2 years experience in developing Android apps /  games Solid knowledge of Core Java and OOPS fundamentals Good knowledge of SQL A fighter with a strong ... More Details',
#   'fundamentals  ,  java  ,  oops  ,  games  ,  sql',
#   'https://www.timesjobs.com/job-detail/android-game-developer-jobslo-consultants-noida-greater-noida-1-to-3-yrs-jobid-0__SLASH__c0MTiO0E9zpSvf__PLUS__uAgZw==&source=srp'),
#  ('JobsLo Consultants',
#   '1 - 3 yrs',
#   'Job Responsibilities : Consistently develop 3d game features of high-level quality ,  on several platforms ,  by gathering requirements ,  designing solutions ,  implementing ... More Details',
#   'c#  ,  c    ,  windows  ,  visual studio  ,  java  ,  games  ,  debugging',
#   'https://www.timesjobs.com/job-detail/unity-game-developer-jobslo-consultants-noida-greater-noida-1-to-3-yrs-jobid-__PLUS__B06tI1GQEFzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Miracle Studios',
#   '1 - 5 yrs',
#   'Is this role right for me? To do this role ,  you will need to:be a team player and a leaderbe a very good Unity Developerbe approachable and listen to what people need and wa... More Details',
#   'turnaround  ,  vmc  ,  scheduling  ,  action  ,  documentation  ,  ideas  ,  maintenance',
#   'https://www.timesjobs.com/job-detail/unity-game-developer-miracle-studios-chandigarh-1-to-5-yrs-jobid-fCNS23xdWZFzpSvf__PLUS__uAgZw==&source=srp'),
#  ('FresherMart',
#   '2 - 5 yrs',
#   'Responsibilities:Design and develop tank mechanics and relevant upgrades.program and execute UI ,  menus ,  and functionalities.Monitor and integrate game system Plugin.design... More Details',
#   'integrate game system  ,   develop 3D games  ,   execute UI',
#   'https://www.timesjobs.com/job-detail/unity-game-developer-freshermart-jaipur-2-to-5-yrs-jobid-We4aMAKFWYBzpSvf__PLUS__uAgZw==&source=srp'),
#  ('The NineHertz',
#   '1 - 4 yrs',
#   'Requirement: Experience: 1-4 YrNumber Of Position: 2Location: Jaipur Excellent knowledge of Unity ,  including experience with scripting ,  textures ,  animati... More Details',
#   'mobile  ,  game development  ,  scripting',
#   'https://www.timesjobs.com/job-detail/unity-game-developer-the-ninehertz-jaipur-1-to-4-yrs-jobid-jUPGdqgT2QRzpSvf__PLUS__uAgZw==&source=srp'),
#  ('StartxLabs',
#   '2 - 5 yrs',
#   'Game Developer  ( Unity / 3D )  Looking for passionate and reliable applicants to join our team! Candidate should have minimum 2-year exp in Unity game development.educational... More Details',
#   'c#  ,  c    ,  opengl  ,  visual studio  ,  debugging  ,  directx',
#   'https://www.timesjobs.com/job-detail/game-developer-unity-3d-startxlabs-delhi-delhi-ncr-2-to-5-yrs-jobid-__PLUS__1aXV3UDDpVzpSvf__PLUS__uAgZw==&source=srp'),
#  ('APPLYCUP HIRING SOLUTIONS LLP',
#   '2 - 5 yrs',
#   'Game Developer-Cocos2djsNoida ,  Uttar Pradesh Qualification : BCA ,  B.Tech , B.Sc Experience : 2 - 5 YearsSkills : it ,  computers ,  programmingJob Description :* Consisten... More Details',
#   'oops  ,  games  ,  debugging  ,  windows',
#   'https://www.timesjobs.com/job-detail/game-developer-cocos2djs-applycup-hiring-solutions-llp-noida-greater-noida-2-to-5-yrs-jobid-NRONcjCaIzVzpSvf__PLUS__uAgZw==&source=srp'),
#  ('APPLYCUP HIRING SOLUTIONS LLP',
#   '0 - 3 yrs',
#   'Unity Game Developer - Animation / c#Jaipur ,  Rajasthan Qualification : BCA ,  B.Tech , B.Sc Experience : 0 - 3 YearsSkills : programming ,  game development ,  BCA ,  BscJob... More Details',
#   'testing  ,  mobile  ,  writing  ,  gui',
#   'https://www.timesjobs.com/job-detail/unity-game-developer-animation-c-applycup-hiring-solutions-llp-jaipur-0-to-3-yrs-jobid-xCXwFJzUkuhzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Smashing Geeks',
#   '0 - 4 yrs',
#   'Unity 3D Game Developer Responsibilities:With strong Unity 3D programming skills ,  you will work closely with other engineers to implement core gameplay features in a hybrid ... More Details',
#   'c    ,  c  ,  mobile  ,  problem solving  ,  graphics  ,  opengl  ,  javascript  ,  java',
#   'https://www.timesjobs.com/job-detail/unity-3d-game-developer-smashing-geeks-delhi-delhi-ncr-0-to-4-yrs-jobid-b27n1EOIGBxzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Linkites Infotech Pvt Ltd',
#   '0 - 3 yrs',
#   'SKILLSExcellent knowledge of Unity ,  including experience with scripting ,  textures ,  animation ,  GUI styles ,  and user session management.Familiarity with level design a... More Details',
#   'testing  ,  mobile  ,  writing  ,  gui',
#   'https://www.timesjobs.com/job-detail/unity-2d-3d-game-developer-linkites-infotech-pvt-ltd-indore-0-to-3-yrs-jobid-SoCfrYs05wVzpSvf__PLUS__uAgZw==&source=srp'),
#  ('APPLYCUP HIRING SOLUTIONS LLP',
#   '1 - 6 yrs',
#   'Game Developer - Unity 3D  ,  JavaScript  ,  HTML C  Jaipur ,  Rajasthan Qualification : BCA ,  B.Tech , B.Sc Experience : 1 - 6 YearsSkills : programming ,  BCA ,  BSC ,  ITJ... More Details',
#   'c#  ,  c    ,  wordpress  ,  augmented reality  ,  javascript  ,  android development  ,  java  ,  linux  ,  html  ,  data structures',
#   'https://www.timesjobs.com/job-detail/game-developer-unity-3d-javascript-html-c-applycup-hiring-solutions-llp-jaipur-1-to-6-yrs-jobid-M90O38Z3qsNzpSvf__PLUS__uAgZw==&source=srp'),
#  ('APPLYCUP HIRING SOLUTIONS LLP',
#   '1 - 6 yrs',
#   'Game Developer - Unity 3D  ,  JavaScript  ,  HTML C  Delhi ,  Delhi Qualification : BCA ,  B.Tech , B.Sc Experience : 1 - 6 YearsSkills : programming ,  javascript ,  BCA ,  I... More Details',
#   'c#  ,  c    ,  wordpress  ,  augmented reality  ,  javascript  ,  android development  ,  java  ,  linux  ,  html  ,  data structures',
#   'https://www.timesjobs.com/job-detail/game-developer-unity-3d-javascript-html-c-applycup-hiring-solutions-llp-delhi-delhi-ncr-1-to-6-yrs-jobid-sEaoIw1tBFNzpSvf__PLUS__uAgZw==&source=srp')]

# %%
 df=pd.DataFrame(data_tuples, columns=['company','year_of_experience','description','skills','link'])

# %%
df.to_csv(r' Game_Developer.csv')

# %%
df
# Out:
#                                          company year_of_experience  \
# 0   NextDoor Global Services\r\n     (More Jobs)          3 - 7 yrs
# 1                              SEVEN CONSULTANCY          2 - 5 yrs
# 2                  APPLYCUP HIRING SOLUTIONS LLP          0 - 3 yrs
# 3                  APPLYCUP HIRING SOLUTIONS LLP          4 - 7 yrs
# 4                                     ASPIRATION          2 - 8 yrs
# 5           TEAMPLUS STAFFING SOLUTION PVT. LTD.          0 - 3 yrs
# 6               Red Apple Technologies Pvt. Ltd.          0 - 3 yrs
# 7                              SEVEN CONSULTANCY          2 - 5 yrs
# 8                  APPLYCUP HIRING SOLUTIONS LLP          2 - 5 yrs
# 9                 Fine Jobs Consultant Pvt. Ltd.          5 - 8 yrs
# 10                            JobsLo Consultants          1 - 3 yrs
# 11                            JobsLo Consultants          1 - 3 yrs
# 12                               Miracle Studios          1 - 5 yrs
# 13                                   FresherMart          2 - 5 yrs
# 14                                 The NineHertz          1 - 4 yrs
# 15                                    StartxLabs          2 - 5 yrs
# 16                 APPLYCUP HIRING SOLUTIONS LLP          2 - 5 yrs
# 17                 APPLYCUP HIRING SOLUTIONS LLP          0 - 3 yrs
# 18                                Smashing Geeks          0 - 4 yrs
# 19                     Linkites Infotech Pvt Ltd          0 - 3 yrs
# 20                 APPLYCUP HIRING SOLUTIONS LLP          1 - 6 yrs
# 21                 APPLYCUP HIRING SOLUTIONS LLP          1 - 6 yrs
#
#                                           description  \
# 0   Requirements: -     Proven working experience ...
# 1   JOB DETAILSDesign ,  architect ,  test and imp...
# 2   Game DeveloperMohali ,  PunjQualification : BC...
# 3   Game DeveloperGurgaon ,  Delhi Qualification :...
# 4   Game Developer For A Leading OTT Platform Comp...
# 5   Key Skills : game developer ,  wireframe ,  ht...
# 6   Excellent knowledge of C   programming languag...
# 7   JOB DETAILSDesign ,  architect ,  test and imp...
# 8   Unity Game DeveloperGurgaon ,  DelhiDate Poste...
# 9   Job DescriptionWe are searching for Game Devel...
# 10  Job Description : 1 to 2 years experience in d...
# 11  Job Responsibilities : Consistently develop 3d...
# 12  Is this role right for me? To do this role ,  ...
# 13  Responsibilities:Design and develop tank mecha...
# 14  Requirement: Experience: 1-4 YrNumber Of Posit...
# 15  Game Developer  ( Unity / 3D )  Looking for pa...
# 16  Game Developer-Cocos2djsNoida ,  Uttar Pradesh...
# 17  Unity Game Developer - Animation / c#Jaipur , ...
# 18  Unity 3D Game Developer Responsibilities:With ...
# 19  SKILLSExcellent knowledge of Unity ,  includin...
# 20  Game Developer - Unity 3D  ,  JavaScript  ,  H...
# 21  Game Developer - Unity 3D  ,  JavaScript  ,  H...
#
#                                                skills  \
# 0   game development  ,   programming languages   ...
# 1   Design  ,   architect  ,   test  ,  Generate g...
# 2   c    ,  database  ,  java  ,  oops  ,  php  , ...
# 3   mobile  ,  svn  ,  team player  ,  javascript ...
# 4   algorithms  ,  webworks  ,  games  ,  data str...
# 5                   rest  ,  html5  ,  games  ,  html
# 6   c#  ,  algorithms  ,  c    ,  c  ,  c   progra...
# 7   product creation  ,  Deliver high quality  ,  ...
# 8   Scripting  ,   Textures  ,   Animation  ,   GU...
# 9   software development  ,  unity3d  ,  game deve...
# 10   fundamentals  ,  java  ,  oops  ,  games  ,  sql
# 11  c#  ,  c    ,  windows  ,  visual studio  ,  j...
# 12  turnaround  ,  vmc  ,  scheduling  ,  action  ...
# 13  integrate game system  ,   develop 3D games  ,...
# 14          mobile  ,  game development  ,  scripting
# 15  c#  ,  c    ,  opengl  ,  visual studio  ,  de...
# 16           oops  ,  games  ,  debugging  ,  windows
# 17             testing  ,  mobile  ,  writing  ,  gui
# 18  c    ,  c  ,  mobile  ,  problem solving  ,  g...
# 19             testing  ,  mobile  ,  writing  ,  gui
# 20  c#  ,  c    ,  wordpress  ,  augmented reality...
# 21  c#  ,  c    ,  wordpress  ,  augmented reality...
#
#                                                  link
# 0   https://www.timesjobs.com/job-detail/senior-ga...
# 1   https://www.timesjobs.com/job-detail/game-deve...
# 2   https://www.timesjobs.com/job-detail/game-deve...
# 3   https://www.timesjobs.com/job-detail/game-deve...
# 4   https://www.timesjobs.com/job-detail/game-deve...
# 5   https://www.timesjobs.com/job-detail/game-deve...
# 6   https://www.timesjobs.com/job-detail/game-deve...
# 7   https://www.timesjobs.com/job-detail/game-deve...
# 8   https://www.timesjobs.com/job-detail/unity-gam...
# 9   https://www.timesjobs.com/job-detail/unity-gam...
# 10  https://www.timesjobs.com/job-detail/android-g...
# 11  https://www.timesjobs.com/job-detail/unity-gam...
# 12  https://www.timesjobs.com/job-detail/unity-gam...
# 13  https://www.timesjobs.com/job-detail/unity-gam...
# 14  https://www.timesjobs.com/job-detail/unity-gam...
# 15  https://www.timesjobs.com/job-detail/game-deve...
# 16  https://www.timesjobs.com/job-detail/game-deve...
# 17  https://www.timesjobs.com/job-detail/unity-gam...
# 18  https://www.timesjobs.com/job-detail/unity-3d-...
# 19  https://www.timesjobs.com/job-detail/unity-2d-...
# 20  https://www.timesjobs.com/job-detail/game-deve...
# 21  https://www.timesjobs.com/job-detail/game-deve...
