# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

URL = ("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=big+data+engineer&txtLocation=Delhi")
#conducting a request of the stated URL above:
page3 = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup( page3.text, "html.parser")

# %%
jobs=soup.find_all('li',class_='clearfix job-bx wht-shd-bx')

# %%
for job in jobs:
    company=[]
    company1= job.find('h3',class_ ='joblist-comp-name')
    company.append(company1.text.strip())

# %%
print(company)
# Out:
# ['JobsLo Consultants']

# %%
company=[]
for job in jobs:
    company1= job.find('h3',class_ ='joblist-comp-name')
    company.append(company1.text.strip())

# %%
print(company)
# Out:
# ['HUDDLEUP\r\n     (More Jobs)', 'Electrobrain modern technologies pvt ltd\r\n     (More Jobs)', 'Electrobrain modern technologies pvt ltd\r\n     (More Jobs)', 'Resource Valley\r\n     (More Jobs)', 'CANVAS27.com Consultant\r\n     (More Jobs)', 'CANVAS27.com Consultant\r\n     (More Jobs)', 'Forstaffing', 'MOUNT TALENT CONSULTING', 'Analytics Vidhya', 'TALPRO', 'Analytics Vidhya', 'TALPRO', 'FresherMart', 'The Economist Intelligence Unit', 'The Economist Intelligence Unit', 'The Economist Group', 'The Economist Group', 'Beno Staffing', 'Nihilent Technologies Pvt. Ltd.', 'Randstad MENA', 'TALPRO', 'TALPRO', 'CAREERXPERTS CONSULTING', 'Adobe Systems Ltd', 'JobsLo Consultants']

# %%
year_of_experience =[]
for job in jobs:
    years=job.find('ul', class_='top-jd-dtl clearfix')
    for years in jobs:
        year=years.find('li').text.replace('card_travel','')
        
        year_of_experience.append(year.strip())

# %%
year_of_experience
# Out:
# ['4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs',
#  '4 - 8 yrs',
#  '3 - 5 yrs',
#  '3 - 5 yrs',
#  '3 - 8 yrs',
#  '1 - 6 yrs',
#  '1 - 6 yrs',
#  '5 - 8 yrs',
#  '1 - 4 yrs',
#  '5 - 7 yrs',
#  '5 - 8 yrs',
#  '4 - 8 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '5 - 8 yrs',
#  '2 - 4 yrs',
#  '4 - 7 yrs',
#  '5 - 8 yrs',
#  '0 - 3 yrs',
#  '2 - 7 yrs',
#  '3 - 10 yrs',
#  '2 - 4 yrs',
#  '10 - 13 yrs',
#  '3 - 6 yrs']

# %%
skills=[]
for job in jobs:
    skills1=job.find('span',class_='srp-skills').text
    skills.append(skills1.strip())

# %%
skills
# Out:
# ['HTML  ,  CSS  ,  JavaScript frameworks  ,  Vue  ,  React  ,  Angular  ,  Amber  ,  Responsive design tools',
#  'SAP Fiori  ,  SAP S  /  4HANA  ,  Oracle  ,  Java  ,  c ++  ,  Html  ,  Javascript  ,  Ajax  ,  Json  ,  MS SQL Server  ,  Sybase ASE',
#  'SAP Fiori  ,  SAP S  /  4HANA  ,  Oracle  ,  Java  ,  c ++  ,  Html  ,  Javascript  ,  Ajax  ,  Json  ,  MS SQL Server  ,  Sybase ASE',
#  'bigdata  ,  hadoop  ,  spark  ,  Hive',
#  'cloud  ,  python  ,  java  ,  query optimization  ,  spark  ,  data warehousing  ,  scratch  ,  hadoop  ,  big data  ,  sql',
#  'cloud  ,  python  ,  java  ,  query optimization  ,  spark  ,  data warehousing  ,  scratch  ,  hadoop  ,  big data  ,  sql',
#  'apache  ,  hadoop  ,  big data  ,  sql',
#  'hive  ,  bi  ,  impala  ,  pig  ,  big data',
#  'hive  ,  sql  ,  pig  ,  java  ,  apache  ,  flume  ,  linux  ,  hadoop  ,  big data  ,  mongodb  ,  hbase  ,  oozie  ,  nosql  ,  cassandra  ,  sqoop',
#  'internet technologies  ,  java  ,  apache  ,  unix shell scripting  ,  hadoop  ,  api  ,  big data  ,  cloud computing  ,  python  ,  sybase  ,  natural language processing  ,  consultant  ,  unix',
#  'hive  ,  c    ,  scala  ,  pig  ,  sql  ,  java  ,  apache  ,  python scripting  ,  git  ,  flume  ,  linux  ,  shell scripting  ,  hadoop  ,  api  ,  big data  ,  cloud computing  ,  hbase  ,  cli  ,  python  ,  oozie  ,  machine learning  ,  nosql  ,  cassandra  ,  infrastructure  ,  hdfs  ,  sqoop',
#  'technical leader  ,  bi  ,  data warehousing  ,  artificial intelligence  ,  sql  ,  internet technologies  ,  java  ,  software engineering  ,  mysql  ,  hadoop  ,  big data  ,  mongodb  ,  github  ,  python  ,  problem solving  ,  nosql  ,  consultant  ,  infrastructure  ,  software developer',
#  'fundamentals  ,  hive  ,  scala  ,  storage  ,  database  ,  json  ,  hadoop  ,  hbase  ,  python  ,  oracle  ,  nosql  ,  cassandra',
#  'hive  ,  orchestration  ,  scala  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python',
#  'hive  ,  orchestration  ,  scala  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python',
#  'hive  ,  orchestration  ,  scala  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python',
#  'hive  ,  orchestration  ,  scala  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python',
#  'hive  ,  python  ,  scala  ,  bi  ,  data warehousing  ,  impala  ,  pig  ,  java  ,  mapreduce  ,  hdfs  ,  hadoop  ,  big data  ,  hbase',
#  'python  ,  data mining  ,  sql  ,  hadoop  ,  big data',
#  'python  ,  orchestration  ,  composer  ,  storage  ,  sql  ,  big data',
#  'hive  ,  internet technologies  ,  java  ,  consultant  ,  hdfs  ,  hadoop  ,  big data',
#  'hive  ,  algorithms  ,  sql  ,  internet technologies  ,  java  ,  data structures  ,  multithreading  ,  mysql  ,  api  ,  big data  ,  oracle  ,  cassandra  ,  hdfs',
#  'hive  ,  scala  ,  data mining  ,  data warehousing  ,  storage  ,  sql  ,  database  ,  java  ,  postgresql  ,  software engineering  ,  mysql  ,  hadoop  ,  big data  ,  cloud computing  ,  python  ,  nosql  ,  cassandra  ,  infrastructure  ,  unix',
#  'python  ,  scala  ,  data warehousing  ,  sql  ,  java  ,  hadoop  ,  big data',
#  'hive  ,  problem solving  ,  ds  ,  production support  ,  java  ,  hadoop  ,  big data']

# %%
description=[]
for job in jobs:
    des=job.find('ul',class_='list-job-dtl clearfix')
    des1=des.li.text.replace('Job Description:','')
    
    
    description.append(des1.strip())

# %%
description
# Out:
# ['Huddle Up LearningRole:      Front End DeveloperFTE:      Full or Part Time.  ( depending on match ) Location:   RemotePOSITION PREVIEW For this role ,  we ar... More Details',
#  'THE ROLEHands-on experience in Leading large End-to-End Implementations and / or large Cloud Migrations of SAP Applications ,  HANA Database Migration ,  Upgrades ,  OS / DB M... More Details',
#  'THE ROLEHands-on experience in Leading large End-to-End Implementations and / or large Cloud Migrations of SAP Applications ,  HANA Database Migration ,  Upgrades ,  OS / DB M... More Details',
#  'Knowledge in Big Data technologiesHadoop ,  Pig ,  Hive andSparkExperience working with any Hadoop platform extensively.Experience in migrating workload from on-premise to clo... More Details',
#  'Solid background on building data pipelines from scratch to produce queryable datasetsDecent knowledge of any programming language like Python / Java or any other scripting la... More Details',
#  'Solid background on building data pipelines from scratch to produce queryable datasetsDecent knowledge of any programming language like Python / Java or any other scripting la... More Details',
#  'Ideally with relevant experience in the range of 5-8 yrs.must have worked on large data sets ,  new age big data frameworks like Apache Spark ,  Apache Flink ,  Hadoop stack.m... More Details',
#  'Roles and ResponsibiesProficient understanding of distributed computing principles Management of Spark clusters ,  with all included services various implementations of Spark ... More Details',
#  'Job Description and Responsibilities:4  years Big Data ecosystem experience along with admin ,  development ,  cloud and app integration experience3  years Consulting experien... More Details',
#  'ResponsibilitiesResponsible to Ingest data from files ,  streams and databases. Process the data with Spark and JavaDevelop programs as part of data cleaning and processingRes... More Details',
#  "Our Big Data capability team is hiring technologists who can produce beautiful  &  functional code to solve complex analytics' problems. If you are an exceptional developer an... More Details",
#  'Roles and ResponsibilitiesThis role requires close collaborations with data ,  engineering ,  and product organizations. His / her job functions includeWork with large data se... More Details',
#  'Seeking experienced BigData  /  NOSQL developers to join our agile team and be part of creating enterprise solutions at scale. The developer will work with a team of database ... More Details',
#  'With a growing global subscriber base and a reputation for insightful analysis and opinion on every aspect of world events ,  The Economist is one of the most widely recognise... More Details',
#  'With a growing global subscriber base and a reputation for insightful analysis and opinion on every aspect of world events ,  The Economist is one of the most widely recognise... More Details',
#  'The Economist Group is the leading source of analysis on international business and world affairs. We deliver world-class ,  thought provoking content through a range of forma... More Details',
#  'With a growing global subscriber base and a reputation for insightful analysis and opinion on every aspect of world events ,  The Economist is one of the most widely recognise... More Details',
#  'What do we do at BluePi:BluePi is a born in cloud organization with one of the main focus area being Big Data and Analytics. At BluePi we solve different business problems for... More Details',
#  'Skills: Monitoring ,  building human-fault-tolerant pipelines ,  addressing continuous integration ,  knowledge of databaseAdministration ,  data cleaningFilter ,  tag ,  join... More Details',
#  'job description data engineer- azure / aws / gcp / big data in gurgaon WIth our esteem client hiring for Data Engineer- Azure / AWS / GCP / Big DataRole  &  Responsibilities T... More Details',
#  'SE / SSE- strong Exp in Java with some exposure in Big Data  ( should have big data conceptual knowledge )  Exp- 2-6 yearsTL- strong Exp in Java   strong Exp in Big Data  some... More Details',
#  'SSE- strong Exp in Java with some exposure in Big Data  ( should have big data conceptual knowledge )  Exp- 3-6 yearsTL- strong Exp in Java   strong Exp in Big Data  some ment... More Details',
#  'As a data engineer ,  you will design ,  build ,  maintain ,  and scale our data pipeline and infrastructure. Here ,  you will be architecting a platform to turn billions of e... More Details',
#  'Our CompanyChanging the world through digital experiences is what Adobes all about. We give everyonefrom emerging artists to global brandseverything they need to design and de... More Details',
#  'Job Description :Our Ideal Candidate : You have a deep interest and passion for technology. You love writing and owning codes and enjoy working with people who will keep chall... More Details']

# %%
link=[]
for job in jobs:
    link1=job.header.h2.a['href']
    link.append(link1)

# %%
link
# Out:
# ['https://www.timesjobs.com/job-detail/front-end-developer-huddleup-delhi-delhi-ncr-gurgaon-mumbai-noida-greater-noida-4-to-8-yrs-jobid-DuP2QqG3ShhzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/business-development-consultant-electrobrain-modern-technologies-pvt-ltd-bengaluru-bangalore-chennai-delhi-ncr-hyderabad-secunderabad-mumbai-3-to-5-yrs-jobid-tj__PLUS__jRtBnv__SLASH__JzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/sap-technology-associate-consultant-platform-basis-electrobrain-modern-technologies-pvt-ltd-bengaluru-bangalore-chennai-delhi-ncr-hyderabad-secunderabad-mumbai-3-to-5-yrs-jobid-V6L1xgJZoL5zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/sr-big-data-engineer-bigdata-developer-a-leading-it-company-gurgaon-3-to-8-yrs-jobid-MsfRHrUwcStzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-canvas27-com-consultant-hyderabad-secunderabad-kolkata-mumbai-noida-greater-noida-pune-1-to-6-yrs-jobid-U7HS3r3Q4BBzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-canvas27-com-consultant-ahmedabad-bengaluru-bangalore-chennai-delhi-ncr-gurgaon-1-to-6-yrs-jobid-ax5tvzx6mIBzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/big-data-engineer-forstaffing-noida-greater-noida-5-to-8-yrs-jobid-zSkyz5hSKzpzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/big-data-engineer-mount-talent-consulting-gurgaon-bengaluru-bangalore-1-to-4-yrs-jobid-QD6VZw2UPotzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/big-data-engineer-analytics-vidhya-gurgaon-mumbai-delhi-delhi-ncr-5-to-7-yrs-jobid-tDL9HI5HixJzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-big-data-talpro-mumbai-delhi-delhi-ncr-bengaluru-bangalore-5-to-8-yrs-jobid-bQDVmEmuCCxzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/lead-big-data-engineer-analytics-vidhya-gurgaon-mumbai-bengaluru-bangalore-4-to-8-yrs-jobid-HD4OJ7Fa8BpzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/big-data-engineer-talpro-delhi-delhi-ncr-jaipur-bengaluru-bangalore-5-to-8-yrs-jobid-4huuVkqlL59zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/big-data-engineer-freshermart-gurgaon-2-to-4-yrs-jobid-2Yg4xKALHdBzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-iii-big-data-the-economist-intelligence-unit-gurgaon-5-to-8-yrs-jobid-yo9i23USA5ZzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-ii-big-data-the-economist-intelligence-unit-gurgaon-2-to-4-yrs-jobid-__SLASH__X8mpzPNhHtzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-iii-big-data-the-economist-group-gurgaon-5-to-8-yrs-jobid-H9B6__PLUS____SLASH__T9eNtzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-ii-big-data-the-economist-group-gurgaon-2-to-4-yrs-jobid-tVVZT7jWzBVzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/big-data-engineer-module-lead-beno-staffing-gurgaon-4-to-7-yrs-jobid-q7__SLASH__AG__PLUS__0EAYlzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-nihilent-technologies-pvt-ltd-gurgaon-5-to-8-yrs-jobid-__SLASH____PLUS__EIL2m0NkNzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-azure-aws-gcp-big-data-randstad-mena-gurgaon-0-to-3-yrs-jobid-S__PLUS__FAL15cdnlzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/big-data-engineer-se-sse-tl-talpro-gurgaon-bengaluru-bangalore-2-to-7-yrs-jobid-FZ3x7ratoTNzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/big-data-engineer-se-sse-tl-talpro-gurgaon-delhi-delhi-ncr-bengaluru-bangalore-3-to-10-yrs-jobid-xQov4meFm3xzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-big-data-cloud-architect-careerxperts-consulting-noida-greater-noida-2-to-4-yrs-jobid-7VPVeqloAu5zpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-adobe-systems-ltd-noida-greater-noida-10-to-13-yrs-jobid-5PcbzhajglxzpSvf__PLUS__uAgZw==&source=srp',
#  'https://www.timesjobs.com/job-detail/data-engineer-jobslo-consultants-noida-greater-noida-3-to-6-yrs-jobid-k47fYjHyJrFzpSvf__PLUS__uAgZw==&source=srp']

# %%
published_date=[]
for job in jobs:
    published_date1=job.find('span',class_='sim-posted').text
    published_date.append(published_date1.strip())

# %%
published_date
# Out:
# ['Work from Home \r\n\t\t    \t\nPosted 2 days ago',
#  'Posted 2 days ago',
#  'Posted 2 days ago',
#  'Posted a month ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 4 days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 6 days ago',
#  'Posted 6 days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 1 day ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted few days ago',
#  'Posted 4 days ago',
#  'Posted few days ago']

# %%
data_tuples = list(zip(company,year_of_experience,description,skills,link))

# %%
data_tuples
# Out:
# [('HUDDLEUP\r\n     (More Jobs)',
#   '4 - 8 yrs',
#   'Huddle Up LearningRole:      Front End DeveloperFTE:      Full or Part Time.  ( depending on match ) Location:   RemotePOSITION PREVIEW For this role ,  we ar... More Details',
#   'HTML  ,  CSS  ,  JavaScript frameworks  ,  Vue  ,  React  ,  Angular  ,  Amber  ,  Responsive design tools',
#   'https://www.timesjobs.com/job-detail/front-end-developer-huddleup-delhi-delhi-ncr-gurgaon-mumbai-noida-greater-noida-4-to-8-yrs-jobid-DuP2QqG3ShhzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Electrobrain modern technologies pvt ltd\r\n     (More Jobs)',
#   '3 - 5 yrs',
#   'THE ROLEHands-on experience in Leading large End-to-End Implementations and / or large Cloud Migrations of SAP Applications ,  HANA Database Migration ,  Upgrades ,  OS / DB M... More Details',
#   'SAP Fiori  ,  SAP S  /  4HANA  ,  Oracle  ,  Java  ,  c ++  ,  Html  ,  Javascript  ,  Ajax  ,  Json  ,  MS SQL Server  ,  Sybase ASE',
#   'https://www.timesjobs.com/job-detail/business-development-consultant-electrobrain-modern-technologies-pvt-ltd-bengaluru-bangalore-chennai-delhi-ncr-hyderabad-secunderabad-mumbai-3-to-5-yrs-jobid-tj__PLUS__jRtBnv__SLASH__JzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Electrobrain modern technologies pvt ltd\r\n     (More Jobs)',
#   '3 - 5 yrs',
#   'THE ROLEHands-on experience in Leading large End-to-End Implementations and / or large Cloud Migrations of SAP Applications ,  HANA Database Migration ,  Upgrades ,  OS / DB M... More Details',
#   'SAP Fiori  ,  SAP S  /  4HANA  ,  Oracle  ,  Java  ,  c ++  ,  Html  ,  Javascript  ,  Ajax  ,  Json  ,  MS SQL Server  ,  Sybase ASE',
#   'https://www.timesjobs.com/job-detail/sap-technology-associate-consultant-platform-basis-electrobrain-modern-technologies-pvt-ltd-bengaluru-bangalore-chennai-delhi-ncr-hyderabad-secunderabad-mumbai-3-to-5-yrs-jobid-V6L1xgJZoL5zpSvf__PLUS__uAgZw==&source=srp'),
#  ('Resource Valley\r\n     (More Jobs)',
#   '3 - 8 yrs',
#   'Knowledge in Big Data technologiesHadoop ,  Pig ,  Hive andSparkExperience working with any Hadoop platform extensively.Experience in migrating workload from on-premise to clo... More Details',
#   'bigdata  ,  hadoop  ,  spark  ,  Hive',
#   'https://www.timesjobs.com/job-detail/sr-big-data-engineer-bigdata-developer-a-leading-it-company-gurgaon-3-to-8-yrs-jobid-MsfRHrUwcStzpSvf__PLUS__uAgZw==&source=srp'),
#  ('CANVAS27.com Consultant\r\n     (More Jobs)',
#   '1 - 6 yrs',
#   'Solid background on building data pipelines from scratch to produce queryable datasetsDecent knowledge of any programming language like Python / Java or any other scripting la... More Details',
#   'cloud  ,  python  ,  java  ,  query optimization  ,  spark  ,  data warehousing  ,  scratch  ,  hadoop  ,  big data  ,  sql',
#   'https://www.timesjobs.com/job-detail/data-engineer-canvas27-com-consultant-hyderabad-secunderabad-kolkata-mumbai-noida-greater-noida-pune-1-to-6-yrs-jobid-U7HS3r3Q4BBzpSvf__PLUS__uAgZw==&source=srp'),
#  ('CANVAS27.com Consultant\r\n     (More Jobs)',
#   '1 - 6 yrs',
#   'Solid background on building data pipelines from scratch to produce queryable datasetsDecent knowledge of any programming language like Python / Java or any other scripting la... More Details',
#   'cloud  ,  python  ,  java  ,  query optimization  ,  spark  ,  data warehousing  ,  scratch  ,  hadoop  ,  big data  ,  sql',
#   'https://www.timesjobs.com/job-detail/data-engineer-canvas27-com-consultant-ahmedabad-bengaluru-bangalore-chennai-delhi-ncr-gurgaon-1-to-6-yrs-jobid-ax5tvzx6mIBzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Forstaffing',
#   '5 - 8 yrs',
#   'Ideally with relevant experience in the range of 5-8 yrs.must have worked on large data sets ,  new age big data frameworks like Apache Spark ,  Apache Flink ,  Hadoop stack.m... More Details',
#   'apache  ,  hadoop  ,  big data  ,  sql',
#   'https://www.timesjobs.com/job-detail/big-data-engineer-forstaffing-noida-greater-noida-5-to-8-yrs-jobid-zSkyz5hSKzpzpSvf__PLUS__uAgZw==&source=srp'),
#  ('MOUNT TALENT CONSULTING',
#   '1 - 4 yrs',
#   'Roles and ResponsibiesProficient understanding of distributed computing principles Management of Spark clusters ,  with all included services various implementations of Spark ... More Details',
#   'hive  ,  bi  ,  impala  ,  pig  ,  big data',
#   'https://www.timesjobs.com/job-detail/big-data-engineer-mount-talent-consulting-gurgaon-bengaluru-bangalore-1-to-4-yrs-jobid-QD6VZw2UPotzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '5 - 7 yrs',
#   'Job Description and Responsibilities:4  years Big Data ecosystem experience along with admin ,  development ,  cloud and app integration experience3  years Consulting experien... More Details',
#   'hive  ,  sql  ,  pig  ,  java  ,  apache  ,  flume  ,  linux  ,  hadoop  ,  big data  ,  mongodb  ,  hbase  ,  oozie  ,  nosql  ,  cassandra  ,  sqoop',
#   'https://www.timesjobs.com/job-detail/big-data-engineer-analytics-vidhya-gurgaon-mumbai-delhi-delhi-ncr-5-to-7-yrs-jobid-tDL9HI5HixJzpSvf__PLUS__uAgZw==&source=srp'),
#  ('TALPRO',
#   '5 - 8 yrs',
#   'ResponsibilitiesResponsible to Ingest data from files ,  streams and databases. Process the data with Spark and JavaDevelop programs as part of data cleaning and processingRes... More Details',
#   'internet technologies  ,  java  ,  apache  ,  unix shell scripting  ,  hadoop  ,  api  ,  big data  ,  cloud computing  ,  python  ,  sybase  ,  natural language processing  ,  consultant  ,  unix',
#   'https://www.timesjobs.com/job-detail/data-engineer-big-data-talpro-mumbai-delhi-delhi-ncr-bengaluru-bangalore-5-to-8-yrs-jobid-bQDVmEmuCCxzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Analytics Vidhya',
#   '4 - 8 yrs',
#   "Our Big Data capability team is hiring technologists who can produce beautiful  &  functional code to solve complex analytics' problems. If you are an exceptional developer an... More Details",
#   'hive  ,  c    ,  scala  ,  pig  ,  sql  ,  java  ,  apache  ,  python scripting  ,  git  ,  flume  ,  linux  ,  shell scripting  ,  hadoop  ,  api  ,  big data  ,  cloud computing  ,  hbase  ,  cli  ,  python  ,  oozie  ,  machine learning  ,  nosql  ,  cassandra  ,  infrastructure  ,  hdfs  ,  sqoop',
#   'https://www.timesjobs.com/job-detail/lead-big-data-engineer-analytics-vidhya-gurgaon-mumbai-bengaluru-bangalore-4-to-8-yrs-jobid-HD4OJ7Fa8BpzpSvf__PLUS__uAgZw==&source=srp'),
#  ('TALPRO',
#   '5 - 8 yrs',
#   'Roles and ResponsibilitiesThis role requires close collaborations with data ,  engineering ,  and product organizations. His / her job functions includeWork with large data se... More Details',
#   'technical leader  ,  bi  ,  data warehousing  ,  artificial intelligence  ,  sql  ,  internet technologies  ,  java  ,  software engineering  ,  mysql  ,  hadoop  ,  big data  ,  mongodb  ,  github  ,  python  ,  problem solving  ,  nosql  ,  consultant  ,  infrastructure  ,  software developer',
#   'https://www.timesjobs.com/job-detail/big-data-engineer-talpro-delhi-delhi-ncr-jaipur-bengaluru-bangalore-5-to-8-yrs-jobid-4huuVkqlL59zpSvf__PLUS__uAgZw==&source=srp'),
#  ('FresherMart',
#   '2 - 4 yrs',
#   'Seeking experienced BigData  /  NOSQL developers to join our agile team and be part of creating enterprise solutions at scale. The developer will work with a team of database ... More Details',
#   'fundamentals  ,  hive  ,  scala  ,  storage  ,  database  ,  json  ,  hadoop  ,  hbase  ,  python  ,  oracle  ,  nosql  ,  cassandra',
#   'https://www.timesjobs.com/job-detail/big-data-engineer-freshermart-gurgaon-2-to-4-yrs-jobid-2Yg4xKALHdBzpSvf__PLUS__uAgZw==&source=srp'),
#  ('The Economist Intelligence Unit',
#   '5 - 8 yrs',
#   'With a growing global subscriber base and a reputation for insightful analysis and opinion on every aspect of world events ,  The Economist is one of the most widely recognise... More Details',
#   'hive  ,  orchestration  ,  scala  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python',
#   'https://www.timesjobs.com/job-detail/data-engineer-iii-big-data-the-economist-intelligence-unit-gurgaon-5-to-8-yrs-jobid-yo9i23USA5ZzpSvf__PLUS__uAgZw==&source=srp'),
#  ('The Economist Intelligence Unit',
#   '2 - 4 yrs',
#   'With a growing global subscriber base and a reputation for insightful analysis and opinion on every aspect of world events ,  The Economist is one of the most widely recognise... More Details',
#   'hive  ,  orchestration  ,  scala  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python',
#   'https://www.timesjobs.com/job-detail/data-engineer-ii-big-data-the-economist-intelligence-unit-gurgaon-2-to-4-yrs-jobid-__SLASH__X8mpzPNhHtzpSvf__PLUS__uAgZw==&source=srp'),
#  ('The Economist Group',
#   '5 - 8 yrs',
#   'The Economist Group is the leading source of analysis on international business and world affairs. We deliver world-class ,  thought provoking content through a range of forma... More Details',
#   'hive  ,  orchestration  ,  scala  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python',
#   'https://www.timesjobs.com/job-detail/data-engineer-iii-big-data-the-economist-group-gurgaon-5-to-8-yrs-jobid-H9B6__PLUS____SLASH__T9eNtzpSvf__PLUS__uAgZw==&source=srp'),
#  ('The Economist Group',
#   '2 - 4 yrs',
#   'With a growing global subscriber base and a reputation for insightful analysis and opinion on every aspect of world events ,  The Economist is one of the most widely recognise... More Details',
#   'hive  ,  orchestration  ,  scala  ,  java  ,  software engineering  ,  hadoop  ,  big data  ,  python',
#   'https://www.timesjobs.com/job-detail/data-engineer-ii-big-data-the-economist-group-gurgaon-2-to-4-yrs-jobid-tVVZT7jWzBVzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Beno Staffing',
#   '4 - 7 yrs',
#   'What do we do at BluePi:BluePi is a born in cloud organization with one of the main focus area being Big Data and Analytics. At BluePi we solve different business problems for... More Details',
#   'hive  ,  python  ,  scala  ,  bi  ,  data warehousing  ,  impala  ,  pig  ,  java  ,  mapreduce  ,  hdfs  ,  hadoop  ,  big data  ,  hbase',
#   'https://www.timesjobs.com/job-detail/big-data-engineer-module-lead-beno-staffing-gurgaon-4-to-7-yrs-jobid-q7__SLASH__AG__PLUS__0EAYlzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Nihilent Technologies Pvt. Ltd.',
#   '5 - 8 yrs',
#   'Skills: Monitoring ,  building human-fault-tolerant pipelines ,  addressing continuous integration ,  knowledge of databaseAdministration ,  data cleaningFilter ,  tag ,  join... More Details',
#   'python  ,  data mining  ,  sql  ,  hadoop  ,  big data',
#   'https://www.timesjobs.com/job-detail/data-engineer-nihilent-technologies-pvt-ltd-gurgaon-5-to-8-yrs-jobid-__SLASH____PLUS__EIL2m0NkNzpSvf__PLUS__uAgZw==&source=srp'),
#  ('Randstad MENA',
#   '0 - 3 yrs',
#   'job description data engineer- azure / aws / gcp / big data in gurgaon WIth our esteem client hiring for Data Engineer- Azure / AWS / GCP / Big DataRole  &  Responsibilities T... More Details',
#   'python  ,  orchestration  ,  composer  ,  storage  ,  sql  ,  big data',
#   'https://www.timesjobs.com/job-detail/data-engineer-azure-aws-gcp-big-data-randstad-mena-gurgaon-0-to-3-yrs-jobid-S__PLUS__FAL15cdnlzpSvf__PLUS__uAgZw==&source=srp'),
#  ('TALPRO',
#   '2 - 7 yrs',
#   'SE / SSE- strong Exp in Java with some exposure in Big Data  ( should have big data conceptual knowledge )  Exp- 2-6 yearsTL- strong Exp in Java   strong Exp in Big Data  some... More Details',
#   'hive  ,  internet technologies  ,  java  ,  consultant  ,  hdfs  ,  hadoop  ,  big data',
#   'https://www.timesjobs.com/job-detail/big-data-engineer-se-sse-tl-talpro-gurgaon-bengaluru-bangalore-2-to-7-yrs-jobid-FZ3x7ratoTNzpSvf__PLUS__uAgZw==&source=srp'),
#  ('TALPRO',
#   '3 - 10 yrs',
#   'SSE- strong Exp in Java with some exposure in Big Data  ( should have big data conceptual knowledge )  Exp- 3-6 yearsTL- strong Exp in Java   strong Exp in Big Data  some ment... More Details',
#   'hive  ,  algorithms  ,  sql  ,  internet technologies  ,  java  ,  data structures  ,  multithreading  ,  mysql  ,  api  ,  big data  ,  oracle  ,  cassandra  ,  hdfs',
#   'https://www.timesjobs.com/job-detail/big-data-engineer-se-sse-tl-talpro-gurgaon-delhi-delhi-ncr-bengaluru-bangalore-3-to-10-yrs-jobid-xQov4meFm3xzpSvf__PLUS__uAgZw==&source=srp'),
#  ('CAREERXPERTS CONSULTING',
#   '2 - 4 yrs',
#   'As a data engineer ,  you will design ,  build ,  maintain ,  and scale our data pipeline and infrastructure. Here ,  you will be architecting a platform to turn billions of e... More Details',
#   'hive  ,  scala  ,  data mining  ,  data warehousing  ,  storage  ,  sql  ,  database  ,  java  ,  postgresql  ,  software engineering  ,  mysql  ,  hadoop  ,  big data  ,  cloud computing  ,  python  ,  nosql  ,  cassandra  ,  infrastructure  ,  unix',
#   'https://www.timesjobs.com/job-detail/data-engineer-big-data-cloud-architect-careerxperts-consulting-noida-greater-noida-2-to-4-yrs-jobid-7VPVeqloAu5zpSvf__PLUS__uAgZw==&source=srp'),
#  ('Adobe Systems Ltd',
#   '10 - 13 yrs',
#   'Our CompanyChanging the world through digital experiences is what Adobes all about. We give everyonefrom emerging artists to global brandseverything they need to design and de... More Details',
#   'python  ,  scala  ,  data warehousing  ,  sql  ,  java  ,  hadoop  ,  big data',
#   'https://www.timesjobs.com/job-detail/data-engineer-adobe-systems-ltd-noida-greater-noida-10-to-13-yrs-jobid-5PcbzhajglxzpSvf__PLUS__uAgZw==&source=srp'),
#  ('JobsLo Consultants',
#   '3 - 6 yrs',
#   'Job Description :Our Ideal Candidate : You have a deep interest and passion for technology. You love writing and owning codes and enjoy working with people who will keep chall... More Details',
#   'hive  ,  problem solving  ,  ds  ,  production support  ,  java  ,  hadoop  ,  big data',
#   'https://www.timesjobs.com/job-detail/data-engineer-jobslo-consultants-noida-greater-noida-3-to-6-yrs-jobid-k47fYjHyJrFzpSvf__PLUS__uAgZw==&source=srp')]

# %%
 df=pd.DataFrame(data_tuples, columns=['company','year_of_experience','description','skills','link'])

# %%
df.to_csv(r'big_data.csv')

# %%
df
# Out:
#                                               company year_of_experience  \
# 0                        HUDDLEUP\r\n     (More Jobs)          4 - 8 yrs
# 1   Electrobrain modern technologies pvt ltd\r\n  ...          3 - 5 yrs
# 2   Electrobrain modern technologies pvt ltd\r\n  ...          3 - 5 yrs
# 3                 Resource Valley\r\n     (More Jobs)          3 - 8 yrs
# 4         CANVAS27.com Consultant\r\n     (More Jobs)          1 - 6 yrs
# 5         CANVAS27.com Consultant\r\n     (More Jobs)          1 - 6 yrs
# 6                                         Forstaffing          5 - 8 yrs
# 7                             MOUNT TALENT CONSULTING          1 - 4 yrs
# 8                                    Analytics Vidhya          5 - 7 yrs
# 9                                              TALPRO          5 - 8 yrs
# 10                                   Analytics Vidhya          4 - 8 yrs
# 11                                             TALPRO          5 - 8 yrs
# 12                                        FresherMart          2 - 4 yrs
# 13                    The Economist Intelligence Unit          5 - 8 yrs
# 14                    The Economist Intelligence Unit          2 - 4 yrs
# 15                                The Economist Group          5 - 8 yrs
# 16                                The Economist Group          2 - 4 yrs
# 17                                      Beno Staffing          4 - 7 yrs
# 18                    Nihilent Technologies Pvt. Ltd.          5 - 8 yrs
# 19                                      Randstad MENA          0 - 3 yrs
# 20                                             TALPRO          2 - 7 yrs
# 21                                             TALPRO         3 - 10 yrs
# 22                            CAREERXPERTS CONSULTING          2 - 4 yrs
# 23                                  Adobe Systems Ltd        10 - 13 yrs
# 24                                 JobsLo Consultants          3 - 6 yrs
#
#                                           description  \
# 0   Huddle Up LearningRole:      Front End Develop...
# 1   THE ROLEHands-on experience in Leading large E...
# 2   THE ROLEHands-on experience in Leading large E...
# 3   Knowledge in Big Data technologiesHadoop ,  Pi...
# 4   Solid background on building data pipelines fr...
# 5   Solid background on building data pipelines fr...
# 6   Ideally with relevant experience in the range ...
# 7   Roles and ResponsibiesProficient understanding...
# 8   Job Description and Responsibilities:4  years ...
# 9   ResponsibilitiesResponsible to Ingest data fro...
# 10  Our Big Data capability team is hiring technol...
# 11  Roles and ResponsibilitiesThis role requires c...
# 12  Seeking experienced BigData  /  NOSQL develope...
# 13  With a growing global subscriber base and a re...
# 14  With a growing global subscriber base and a re...
# 15  The Economist Group is the leading source of a...
# 16  With a growing global subscriber base and a re...
# 17  What do we do at BluePi:BluePi is a born in cl...
# 18  Skills: Monitoring ,  building human-fault-tol...
# 19  job description data engineer- azure / aws / g...
# 20  SE / SSE- strong Exp in Java with some exposur...
# 21  SSE- strong Exp in Java with some exposure in ...
# 22  As a data engineer ,  you will design ,  build...
# 23  Our CompanyChanging the world through digital ...
# 24  Job Description :Our Ideal Candidate : You hav...
#
#                                                skills  \
# 0   HTML  ,  CSS  ,  JavaScript frameworks  ,  Vue...
# 1   SAP Fiori  ,  SAP S  /  4HANA  ,  Oracle  ,  J...
# 2   SAP Fiori  ,  SAP S  /  4HANA  ,  Oracle  ,  J...
# 3               bigdata  ,  hadoop  ,  spark  ,  Hive
# 4   cloud  ,  python  ,  java  ,  query optimizati...
# 5   cloud  ,  python  ,  java  ,  query optimizati...
# 6              apache  ,  hadoop  ,  big data  ,  sql
# 7         hive  ,  bi  ,  impala  ,  pig  ,  big data
# 8   hive  ,  sql  ,  pig  ,  java  ,  apache  ,  f...
# 9   internet technologies  ,  java  ,  apache  ,  ...
# 10  hive  ,  c    ,  scala  ,  pig  ,  sql  ,  jav...
# 11  technical leader  ,  bi  ,  data warehousing  ...
# 12  fundamentals  ,  hive  ,  scala  ,  storage  ,...
# 13  hive  ,  orchestration  ,  scala  ,  java  ,  ...
# 14  hive  ,  orchestration  ,  scala  ,  java  ,  ...
# 15  hive  ,  orchestration  ,  scala  ,  java  ,  ...
# 16  hive  ,  orchestration  ,  scala  ,  java  ,  ...
# 17  hive  ,  python  ,  scala  ,  bi  ,  data ware...
# 18  python  ,  data mining  ,  sql  ,  hadoop  ,  ...
# 19  python  ,  orchestration  ,  composer  ,  stor...
# 20  hive  ,  internet technologies  ,  java  ,  co...
# 21  hive  ,  algorithms  ,  sql  ,  internet techn...
# 22  hive  ,  scala  ,  data mining  ,  data wareho...
# 23  python  ,  scala  ,  data warehousing  ,  sql ...
# 24  hive  ,  problem solving  ,  ds  ,  production...
#
#                                                  link
# 0   https://www.timesjobs.com/job-detail/front-end...
# 1   https://www.timesjobs.com/job-detail/business-...
# 2   https://www.timesjobs.com/job-detail/sap-techn...
# 3   https://www.timesjobs.com/job-detail/sr-big-da...
# 4   https://www.timesjobs.com/job-detail/data-engi...
# 5   https://www.timesjobs.com/job-detail/data-engi...
# 6   https://www.timesjobs.com/job-detail/big-data-...
# 7   https://www.timesjobs.com/job-detail/big-data-...
# 8   https://www.timesjobs.com/job-detail/big-data-...
# 9   https://www.timesjobs.com/job-detail/data-engi...
# 10  https://www.timesjobs.com/job-detail/lead-big-...
# 11  https://www.timesjobs.com/job-detail/big-data-...
# 12  https://www.timesjobs.com/job-detail/big-data-...
# 13  https://www.timesjobs.com/job-detail/data-engi...
# 14  https://www.timesjobs.com/job-detail/data-engi...
# 15  https://www.timesjobs.com/job-detail/data-engi...
# 16  https://www.timesjobs.com/job-detail/data-engi...
# 17  https://www.timesjobs.com/job-detail/big-data-...
# 18  https://www.timesjobs.com/job-detail/data-engi...
# 19  https://www.timesjobs.com/job-detail/data-engi...
# 20  https://www.timesjobs.com/job-detail/big-data-...
# 21  https://www.timesjobs.com/job-detail/big-data-...
# 22  https://www.timesjobs.com/job-detail/data-engi...
# 23  https://www.timesjobs.com/job-detail/data-engi...
# 24  https://www.timesjobs.com/job-detail/data-engi...
